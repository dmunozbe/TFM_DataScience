# %% [markdown]
# <a href="https://colab.research.google.com/github/dmunozbe/TFM_DataScience/blob/main/NB_Movil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Movil.** Indicador nº 74 de la ISO-37120:

# %% [markdown]
# De acuerdo con el objetivo principal del presente TFM, se han recopilado datos del porcentaje de poblacion que tiene acceso a movil en Barcelona a nivel de distrito facilitadas por el Departament d’Anàlisi Oficina Municipal de Dades [www.barcelona.cat
# ](https://ajuntament.barcelona.cat/estadistica/catala/Estadistiques_per_territori/Documents/districtes/index.htm).

# %% [markdown]
# ## Carga del conjunto de datos

# %% [markdown]
# Cargamos en un dataframe el xlsx obtenido desde el año 2016 hasta 2022 sobre el porcentaje de movil en la ciudad de Barcelona

# %%
# Importamos las librerias necesarias
#import requests
import os
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import geopandas as gpd
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.cm import viridis
import warnings

# %%
def cargar_xlsx(ruta):
    try:
        # Cargar el archivo CSV en un DataFrame de pandas
        dataframe = pd.read_excel(ruta)
        return dataframe
    except Exception as e:
        print("Error al cargar el archivo CSV:", e)
        return None

# %%
# Directorio del indicador 1
directorio ='/content/drive/MyDrive/UOC/TFM/Datasets Indicadores/Básico/Telecomunicaciones e innovacion/Indicador_74_Movil'

# Lista de archivos CSV en el directorio
archivos_xlsx = [archivo for archivo in os.listdir(directorio) if archivo.endswith('.xlsx')]

# Lista para almacenar los DataFrames de cada archivo CSV
dfs = []

# Iterar sobre cada archivo CSV y cargarlo en un DataFrame
for archivo in archivos_xlsx:
    ruta_archivo = os.path.join(directorio, archivo)
    df = cargar_xlsx(ruta_archivo)
    dfs.append(df)

# Concatenar todos los DataFrames en un solo DataFrame
df_final = pd.concat(dfs, ignore_index=True)

# %%
# Mostramos las primeras filas del dataframe
df_final.head()
# Out:
#    Codi_Districte Nom_Districte   Any  Movil
# 0               1  Ciutat Vella  2016   96.3
# 1               1  Ciutat Vella  2017   96.6
# 2               1  Ciutat Vella  2018   99.0
# 3               1  Ciutat Vella  2019   98.8
# 4               1  Ciutat Vella  2020   98.5

# %%
# Observamos el numero y los nombres de los atributos, el numero de filas y si hay missing-values o no
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Codi_Districte  70 non-null     int64
#  1   Nom_Districte   70 non-null     object
#  2   Any             70 non-null     int64
#  3   Movil           70 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.3+ KB

# %% [markdown]
# El dataset se compone de un total de 9 columnas:
#
# *   **Codi_Districte:** Codigo del distrito de Barcelona
# *   **Nom_Districte:** Nombre del distrito de Barcelona
# *   **Any:** Año en el que se recogieron los datos
# *   **Movil:** Porcentaje de uso de movil

# %%
# Analizamos las variables numericas
df_final.describe()
# Out:
#        Codi_Districte          Any      Movil
# count        70.00000    70.000000  70.000000
# mean          5.50000  2019.000000  98.308571
# std           2.89302     2.014441   1.337068
# min           1.00000  2016.000000  91.200000
# 25%           3.00000  2017.000000  97.525000
# 50%           5.50000  2019.000000  98.650000
# 75%           8.00000  2021.000000  99.200000
# max          10.00000  2022.000000  99.800000

# %% [markdown]
# Analizando cada una de las variables numericas vemos que la variable:
# *   **Codi_Districte:** aunque es una variable numerica corresponde con valores categoricos.
# *   **Any:** es integra y contiene la información correcta.
# *   **Movil:** es integra y contiene la información correcta.

# %%
# Visualizamos la distribución de la principal variable numerica con un histograma
plt.figure(figsize=(10, 6))
sns.histplot(df_final['Movil'], bins=20, kde=True)
plt.title('Distribución de Movil')
plt.xlabel('Movil')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# Verificamos que si hay datos faltantes

# %%
df_final.isnull().sum()
# Out:
# Codi_Districte    0
# Nom_Districte     0
# Any               0
# Movil             0
# dtype: int64

# %% [markdown]
# Dado que se trata de un dataset obtenido de un excel manipulado, los datos no necesitan limpieza de datos

# %% [markdown]
# ## Creación de .csv

# %% [markdown]
# Obtenemos el archivo datosParticipacion.csv con los datos del dataframe resultante

# %%
# Guardar el DataFrame en un archivo CSV
df_final.to_csv('/content/drive/MyDrive/UOC/TFM/Datasets definitivos/datos_74_Movil.csv', index=False)

# %% [markdown]
# ## Análisis Exploratorio de Datos (EDA)

# %% [markdown]
# Una vez tenemos los datos limpios continuamos con la exploracion inicial de los datos

# %% [markdown]
# ### Variable continua porcentaje de uso de Movil (Movil)

# %%
# Visualizamos la distribución de la principal variable numerica con un histograma
plt.figure(figsize=(10, 6))
sns.histplot(df_final['Movil'], bins=20, kde=True)
plt.title('Distribución de Movil')
plt.xlabel('Movil')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Crear diagrama de caja para la variable continua "ParadosReg" en funcion de la variable categorica "Any"
plt.figure(figsize=(15, 8))
sns.boxplot(x='Any', y='Movil', data=df_final)
plt.title('Boxplot por año para la variable "Movil" en la ciudad de Barcelona')

# Mostrar el diagrama de caja
plt.show()

# %%
# Creamos un diagrama de linea
plt.figure(figsize=(15, 8))
sns.lineplot(data=df_final, x='Any', y='Movil', marker='o')# Graficar los valores de la variable continua
plt.title('Diagrama de Linea para la variable Movil por año')
plt.xlabel('Any')
plt.ylabel('Movil')

plt.show()

# %%
# Creamos un diagrama de linea
plt.figure(figsize=(15, 8))


sns.lineplot(data=df_final, x='Any', y='Movil', hue='Nom_Districte', marker='o')# Graficar los valores de la variable continua
plt.title('Diagrama de Linea para la variable Movil y los diferentes distritos de Barcelona')
plt.xlabel('Any')
plt.ylabel('Movil')
plt.legend(title='Distritos', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(df_final['Any'].unique())

# Sacamos la leyenda fuera del grafico

plt.show()

# %% [markdown]
# ## Carga del Shapefile

# %% [markdown]
# Cargamos el archivo tipo shape con los 10 distritos de Barcelona

# %%
# Cargar el archivo shapefile de los distritos de Barcelona
barcelona_distritos = gpd.read_file("/content/drive/MyDrive/UOC/TFM/Datasets Indicadores/Grafo viario de las calles de la ciudad de Barcelona/BCN_UNITATS_ADM/0301040100_Districtes_UNITATS_ADM.shp")

# Mostrar información básica sobre el shapefile
barcelona_distritos.head()
# Out:
#   ID_ANNEX ANNEXDESCR ID_TEMA               TEMA_DESCR ID_CONJUNT  CONJ_DESCR  \
# 0       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 1       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 2       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 3       01   Grup - I    0104  Unitats Administratives     010412  Districtes
# 4       01   Grup - I    0104  Unitats Administratives     010412  Districtes
#
#   ID_SUBCONJ SCONJ_DESC  ID_ELEMENT           ELEM_DESCR  ... ESTIL_ID_V  \
# 0   01041201  Districte  0104120101  LÃ­mit de districte  ...          0
# 1   01041201  Districte  0104120101  LÃ­mit de districte  ...          0
# 2   01041201  Districte  0104120101  LÃ­mit de districte  ...          0
# 3   01041201  Districte  0104120101  LÃ­mit de districte  ...          0
# 4   01041201  Districte  0104120101  LÃ­mit de districte  ...          0
#
#   ESTIL_QGIS VALOR1QGIS VALOR2QGIS COL_FARCIT FCOL_DESCR FHEX_COLOR COL_DESCR  \
# 0     SÃ²lid          0          0          1      Negre    #000000     Negre
# 1     SÃ²lid          0          0          1      Negre    #000000     Negre
# 2     SÃ²lid          0          0          1      Negre    #000000     Negre
# 3     SÃ²lid          0          0          1      Negre    #000000     Negre
# 4     SÃ²lid          0          0          1      Negre    #000000     Negre
#
#   HEX_COLOR7                                           geometry
# 0    #000000  POLYGON ((431733.736 4582441.816, 431827.673 4...
# 1    #000000  POLYGON ((432033.184 4583665.032, 432032.069 4...
# 2    #000000  MULTIPOLYGON (((428773.911 4580873.742, 428833...
# 3    #000000  POLYGON ((425054.670 4583672.560, 425062.830 4...
# 4    #000000  MULTIPOLYGON (((422563.071 4587486.743, 422568...
#
# [5 rows x 49 columns]

# %%
# Convertimos el tipo de valor de la variable distrito a entero
barcelona_distritos['DISTRICTE'] = barcelona_distritos['DISTRICTE'].astype(int)

# %%
# Mostramos la nomenclatura para los graficos posteriores
print (df_final[['Codi_Districte', 'Nom_Districte']].drop_duplicates().to_string(index=False))
# Out:
#  Codi_Districte      Nom_Districte
#               1       Ciutat Vella
#               2           Eixample
#               3     Sants-Montjuïc
#               4          Les Corts
#               5 Sarrià-SantGervasi
#               6             Gràcia
#               7     Horta-Guinardó
#               8         Nou Barris
#               9        Sant Andreu
#              10         Sant Martí

# %%
# Suprimir todas las advertencias
warnings.filterwarnings("ignore")

plt.figure(figsize=(15, 80))

# Definir el valor máximo y mínimo global
max_global = df_final['Movil'].max()
min_global = df_final['Movil'].min()

# Crear un colormap Viridis
viridis_cmap = viridis

# Iterar sobre cada año para crear un gráfico para cada uno
for i, year in enumerate(df_final['Any'].unique(), start=1):

    plt.subplot(13, 2, i)
    # Filtrar los datos para el año actual
    datos_year = df_final[df_final['Any'] == year]

    # Combinar los datos con el shapefile
    distritos_year = barcelona_distritos.merge(datos_year, how='left', left_on='DISTRICTE', right_on='Codi_Districte') # Combinar datos CSV y Shapefile

    # Añadir los nombres de los distritos
    for idx, row in barcelona_distritos.iterrows():
        plt.text(row.geometry.centroid.x, row.geometry.centroid.y, row['DISTRICTE'], fontsize=8, color='white')

    # Crear el mapa de los distritos de Barcelona en el año actual con colores
    plt.title(f"Porcentaje de uso de Movil por distrito en Barcelona en {year}")

    distritos_year.plot(ax=plt.gca(),column='Movil', cmap=viridis_cmap, linewidth=0.8, edgecolor='0.8', norm=plt.Normalize(vmin=min_global, vmax=max_global))

    # Añadir una barra de color para mostrar la escala
    sm = plt.cm.ScalarMappable(cmap=viridis_cmap, norm=plt.Normalize(vmin=min_global, vmax=max_global))
    sm._A = []
    # Crear la leyenda con un gradiente de color
    cbar = plt.colorbar(sm, ax=plt.gca())
    cbar.set_label('% uso')  # Establece el nombre de la variable
