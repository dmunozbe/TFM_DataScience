# %% [markdown]
# <a href="https://colab.research.google.com/github/dmunozbe/TFM_DataScience/blob/main/Forecasting/05.%20Sarria-Sant%20Gervasi/Forecasting_(Consumo).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Forecasting**
#
#
# 1. [Importar bibliotecas](#Importar-bibliotecas)
# 2. [Carga de datos](#Carga-de-datos)
# 3. [Preparacion de los datos](#Preparacion-de-los-datos)
# 4. [Analisis por grupo de indicadores (Consumo)](#Analisis-por-grupo-de-indicadores-(consumo))
#   - [Preparacion de datos](#Preparacion-de-datos)
#   - [Analisis Exploratorio](#Analisis-Exploratorio)
#   - [Modelo VAR](#Modelo-VAR)
#   - [Modelo VARMAX](#Modelo-VARMAX)
# 5. [Conclusiones](#Conclusiones)

# %% [markdown]
# **Forecasting** es el proceso de predecir eventos futuros basados en patrones históricos y datos existentes.
#
# El objetivo principal es el de hacer predicciones precisas sobre el futuro utilizando datos pasados y presentes y se utiliza en una amplia variaedad de constextos, como en finanzas, meteorologia, ventas entre otros

# %% [markdown]
# ##Importar bibliotecas

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn import metrics


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##Carga de datos

# %%
# Cargar datos
data = pd.read_csv('/content/drive/MyDrive/UOC/TFM/Datasets definitivos/Final.csv')
data.head()
# Out:
#     Any  Trimestre  Mes  Codi_Districte Nom_Districte  Codi_Barri Nom_Barri  \
# 0  2014          1    1               1  Ciutat Vella           1  el Raval
# 1  2014          1    2               1  Ciutat Vella           1  el Raval
# 2  2014          1    3               1  Ciutat Vella           1  el Raval
# 3  2014          2    4               1  Ciutat Vella           1  el Raval
# 4  2014          2    5               1  Ciutat Vella           1  el Raval
#
#    Compraventa_Unitario  ParadosReg  Sin_Estudios  ...  Internet  Movil  \
# 0                2813.0        4588           NaN  ...       NaN    NaN
# 1                2813.0        4539           NaN  ...       NaN    NaN
# 2                2813.0        4572           NaN  ...       NaN    NaN
# 3                2948.8        4510           NaN  ...       NaN    NaN
# 4                2948.8        4379           NaN  ...       NaN    NaN
#
#    Index_Turisme  Index_Motos  Index_Ciclomotors  Index_Furgonetes  \
# 0            NaN          NaN                NaN               NaN
# 1            NaN          NaN                NaN               NaN
# 2            NaN          NaN                NaN               NaN
# 3            NaN          NaN                NaN               NaN
# 4            NaN          NaN                NaN               NaN
#
#    Index_Camions  Index_Resta  Zona Verde (m²)  m² por habitante
# 0            NaN          NaN         628919.0               6.2
# 1            NaN          NaN         628919.0               6.2
# 2            NaN          NaN         628919.0               6.2
# 3            NaN          NaN         628919.0               6.2
# 4            NaN          NaN         628919.0               6.2
#
# [5 rows x 31 columns]

# %%
print(data.dtypes)
# Out:
# Any                             int64
# Trimestre                       int64
# Mes                             int64
# Codi_Districte                  int64
# Nom_Districte                  object
# Codi_Barri                      int64
# Nom_Barri                      object
# Compraventa_Unitario          float64
# ParadosReg                      int64
# Sin_Estudios                  float64
# Solo_Estudios_Obligatorios    float64
# Bachillerato                  float64
# Estudios_Universitarios       float64
# Estudios_Obligatorios         float64
# ConsumIndustria               float64
# ConsumResidencial             float64
# ConsumServeis                 float64
# Pm25                          float64
# Pm10                          float64
# Participacion                 float64
# AñosEspVida                   float64
# Internet                      float64
# Movil                         float64
# Index_Turisme                 float64
# Index_Motos                   float64
# Index_Ciclomotors             float64
# Index_Furgonetes              float64
# Index_Camions                 float64
# Index_Resta                   float64
# Zona Verde (m²)               float64
# m² por habitante              float64
# dtype: object

# %% [markdown]
# ##Preparacion de los datos

# %% [markdown]
# Ahora comprobamos cuantos valores NaN alberga el dataframe

# %%
data.isnull().sum()
# Out:
# Any                              0
# Trimestre                        0
# Mes                              0
# Codi_Districte                   0
# Nom_Districte                    0
# Codi_Barri                       0
# Nom_Barri                        0
# Compraventa_Unitario             0
# ParadosReg                       0
# Sin_Estudios                  2409
# Solo_Estudios_Obligatorios    2409
# Bachillerato                  2409
# Estudios_Universitarios       2409
# Estudios_Obligatorios         2409
# ConsumIndustria               4380
# ConsumResidencial             4380
# ConsumServeis                 4380
# Pm25                          4161
# Pm10                          4161
# Participacion                    0
# AñosEspVida                   3573
# Internet                      2409
# Movil                         2409
# Index_Turisme                 5913
# Index_Motos                   5913
# Index_Ciclomotors             5913
# Index_Furgonetes              5913
# Index_Camions                 5913
# Index_Resta                   5913
# Zona Verde (m²)               1533
# m² por habitante              1533
# dtype: int64

# %% [markdown]
# El objetivo principal del TFM es analizar el valor de compraventa en la ciudad de Barcelona a partir de los indicadores de la ISO 37120.
#
# Como serie temporal principal tenemos el valor de compraventa (unitario) por barrio desde 2014 hasta 2023 y por otro lado, tenemos las diferentes series temporales que corresponden a los indicadores.
#
# Como se puede observar muchos de los indicadores obtenidos, tienen valores NaN. Esto se debe a que no hemos obtenido datos en el mismo rango de fechas que la serie principal. Este hecho limita el analisis de datos de forma global, ya que cada indicador tiene su casuistica.
#
# Es por ello que se tendra que realizar el analisis por grupos de indicadores.
#
# *   Paro
# *   Estudios
# *   Consumo de energia
# *   Contaminacion
# *   Participacion electoral
# *   Esperanza de vida
# *   Tecnologia
# *   Indice Motor
# *   Zonas Verdes
#
# En un principio el estudio se realizara para toda la ciudad de Barcelona.

# %% [markdown]
# ## Analisis por grupo de indicadores (Estudios)

# %% [markdown]
# ### Preparacion de datos

# %%
df_sel = data[['Any','Trimestre','Mes','Codi_Districte','Nom_Districte','Codi_Barri','Nom_Barri','Compraventa_Unitario','ConsumIndustria','ConsumResidencial','ConsumServeis']]

# %%
df_cont = df_sel.dropna()

# %%
df_cont.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4161 entries, 4380 to 8540
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Any                   4161 non-null   int64
#  1   Trimestre             4161 non-null   int64
#  2   Mes                   4161 non-null   int64
#  3   Codi_Districte        4161 non-null   int64
#  4   Nom_Districte         4161 non-null   object
#  5   Codi_Barri            4161 non-null   int64
#  6   Nom_Barri             4161 non-null   object
#  7   Compraventa_Unitario  4161 non-null   float64
#  8   ConsumIndustria       4161 non-null   float64
#  9   ConsumResidencial     4161 non-null   float64
#  10  ConsumServeis         4161 non-null   float64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 390.1+ KB

# %%
# Creamos la variable de fecha de la siguiente manera:
# Agregar un día fijo para cada mes, por ejemplo, el día 1
df_cont['Fecha'] = pd.to_datetime(df_cont['Any'].astype(str) + '-' + df_cont['Mes'].astype(str) + '-1')

# %%
# Modificamos el indice del dataset por la fecha
df_contI = df_cont.set_index('Fecha')

# %%
df_contI.head()
# Out:
#              Any  Trimestre  Mes  Codi_Districte Nom_Districte  Codi_Barri  \
# Fecha
# 2019-01-01  2019          1    1               1  Ciutat Vella           1
# 2019-02-01  2019          1    2               1  Ciutat Vella           1
# 2019-03-01  2019          1    3               1  Ciutat Vella           1
# 2019-04-01  2019          2    4               1  Ciutat Vella           1
# 2019-05-01  2019          2    5               1  Ciutat Vella           1
#
#            Nom_Barri  Compraventa_Unitario  ConsumIndustria  \
# Fecha
# 2019-01-01  el Raval                3775.1       16927294.0
# 2019-02-01  el Raval                3775.1       16399421.0
# 2019-03-01  el Raval                3775.1       18517557.0
# 2019-04-01  el Raval                3838.4       17246043.0
# 2019-05-01  el Raval                3838.4       18634709.0
#
#             ConsumResidencial  ConsumServeis
# Fecha
# 2019-01-01         18828371.0     48896299.0
# 2019-02-01         15384687.0     43178847.0
# 2019-03-01         14925799.0     44246280.0
# 2019-04-01         13804105.0     42670266.0
# 2019-05-01         13852496.0     46359256.0

# %% [markdown]
# ### Analisis Exploratorio

# %% [markdown]
# Filtramos los datos por el distrito de Sarrià-Sant Gervasi -> Codi_Districte = 5

# %%
df_contFiltrado = df_contI[df_contI['Codi_Districte'] == 5]

# %%
# Agrupamos los datos
df =df_contFiltrado.drop(columns=['Any','Trimestre','Mes','Codi_Districte','Nom_Districte','Codi_Barri','Nom_Barri']).groupby('Fecha').mean()

# %%
df.head()
# Out:
#             Compraventa_Unitario  ConsumIndustria  ConsumResidencial  \
# Fecha
# 2019-01-01           5455.166667    954431.500000       1.570854e+07
# 2019-02-01           5455.166667    812811.166667       1.261143e+07
# 2019-03-01           5455.166667    831536.166667       1.217628e+07
# 2019-04-01           5336.233333    774778.333333       1.111069e+07
# 2019-05-01           5336.233333    817628.333333       1.095021e+07
#
#             ConsumServeis
# Fecha
# 2019-01-01   1.862686e+07
# 2019-02-01   1.626656e+07
# 2019-03-01   1.683038e+07
# 2019-04-01   1.654041e+07
# 2019-05-01   1.736939e+07

# %%
fig, axes = plt.subplots(nrows = int(len(df.columns)), ncols = 1, dpi = 100, figsize = (14,15))
unidades = ['€/m²', 'MW/h','MW/h', 'MW/h']
colores = ['#FF5733', '#3498DB','#3498DB','#3498DB']

for i, (col,ax) in enumerate(zip(df.columns, axes.flatten())):
    df[col].plot(color = colores[i], legend = True, ax = ax)
    ax.set_ylabel(unidades[i])  # Establecer etiqueta del eje y
plt.show()

# %% [markdown]
# Cada una de las series tiene patrones de tendencia muy diferentes entre si

# %%
corr=df.corr()
corr
# Out:
#                       Compraventa_Unitario  ConsumIndustria  \
# Compraventa_Unitario              1.000000        -0.078628
# ConsumIndustria                  -0.078628         1.000000
# ConsumResidencial                -0.124281         0.346343
# ConsumServeis                     0.326272         0.609975
#
#                       ConsumResidencial  ConsumServeis
# Compraventa_Unitario          -0.124281       0.326272
# ConsumIndustria                0.346343       0.609975
# ConsumResidencial              1.000000       0.175368
# ConsumServeis                  0.175368       1.000000

# %%
import seaborn as sb
fig, ax = plt.subplots(figsize=(12, 10))

sb.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values, annot=True,vmax=1, vmin=-1, cmap =sb.diverging_palette(220, 10, as_cmap=True),center=0,ax=ax )
plt.show()

# %% [markdown]
# Tambien podemos observar correlaciones parciales entre 2 o 3 variables de consumo, pero nada de correlacion con la Compraventa_Unitario

# %% [markdown]
# ### Modelo VAR

# %% [markdown]
# El modelo VAR es una extension del modelo ARIMA para multiples series temporales, es decir en vez de modelar una sola srie temporal, el VAR modela simultaneamente todas las series temporales de un sistema.
# Cada serie temporal se regresa en función de usus propios valores pasados y de los valores pasados de las otras series temporales.
# **Es util cuando las diferentes series temporales estan interrelacionadas y se influyen mutuamente.**

# %% [markdown]
# ##### Dividir los datos en conjunto de Entrenamiento y Prueba

# %% [markdown]
# El modelo VAR se ajustará al conjunto de entrenamiento X_train y luego se utilizará el modelo para pronosticar las observaciones futuras. Estos pronósticos se compararán con los datos reales del conjunto de prueba.
#
#
#
# ---

# %%
fecha_division = '2023-01-01'

X_train, X_test = df[df.index<fecha_division], df[df.index>=fecha_division]
print(X_train.shape, X_test.shape)
# Out:
# (48, 4) (9, 4)

# %% [markdown]
# ##### Prueba de estacionariedad

# %% [markdown]
# Necesitamos que los datos sean estacionarios para poder usar el modelo VAR. Vamos a averiguarlo haciendo un Test de Dickey-Fuller aumentado, a cada variable univariante que tiene nuestro dataset.

# %%
import statsmodels.tsa.stattools as sts

# %%
def augmented_dickey_fuller_statistics(time_series):
  result = sts.adfuller(time_series.values)
  print('p-value: %f' % result[1])

print('Test de Dickey-Fuller Aumentado:')
for i in range(len(X_train.columns)):
  print('Serie de tiempo',X_train.columns[i])
  augmented_dickey_fuller_statistics(X_train.iloc[:,i])
# Out:
# Test de Dickey-Fuller Aumentado:
# Serie de tiempo Compraventa_Unitario
# p-value: 0.333200
# Serie de tiempo ConsumIndustria
# p-value: 0.049484
# Serie de tiempo ConsumResidencial
# p-value: 0.000001
# Serie de tiempo ConsumServeis
# p-value: 0.057989

# %% [markdown]
# Los p-valores son mayores que 0.05, con lo cual no se rechaza la hipótesis nula de que la serie no es estacionaria. Habría que transformar los datos porque no se puede confirmar estacionariedad.

# %%
#Diferenciando por primera vez
X_train_transformed=X_train.diff().dropna()
X_train_transformed.head()
# Out:
#             Compraventa_Unitario  ConsumIndustria  ConsumResidencial  \
# Fecha
# 2019-02-01              0.000000   -141620.333333      -3.097110e+06
# 2019-03-01              0.000000     18725.000000      -4.351532e+05
# 2019-04-01           -118.933333    -56757.833333      -1.065591e+06
# 2019-05-01              0.000000     42850.000000      -1.604777e+05
# 2019-06-01              0.000000     34203.666667      -2.022585e+05
#
#             ConsumServeis
# Fecha
# 2019-02-01  -2.360303e+06
# 2019-03-01   5.638198e+05
# 2019-04-01  -2.899718e+05
# 2019-05-01   8.289825e+05
# 2019-06-01   2.553300e+05

# %%
# Plot
fig, axes = plt.subplots(nrows=4, ncols=1, dpi=120, figsize=(12,6))
for i, ax in enumerate(axes.flatten()):
    data = X_train_transformed[X_train_transformed.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(X_train_transformed.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
print('Test de Dickey-Fuller Aumentado 2da vez:')
for i in range(len(X_train_transformed.columns)):
  print('Serie de tiempo transformada', 'Variable', X_train_transformed.columns[i])
  augmented_dickey_fuller_statistics(X_train_transformed.iloc[:,i])
# Out:
# Test de Dickey-Fuller Aumentado 2da vez:
# Serie de tiempo transformada Variable Compraventa_Unitario
# p-value: 0.000410
# Serie de tiempo transformada Variable ConsumIndustria
# p-value: 0.055907
# Serie de tiempo transformada Variable ConsumResidencial
# p-value: 0.000000
# Serie de tiempo transformada Variable ConsumServeis
# p-value: 0.004797

# %%
#Diferenciando por segunda vez
X_train_transformed=X_train.diff().diff().dropna()
X_train_transformed.head()
# Out:
#             Compraventa_Unitario  ConsumIndustria  ConsumResidencial  \
# Fecha
# 2019-03-01              0.000000    160345.333333       2.661956e+06
# 2019-04-01           -118.933333    -75482.833333      -6.304380e+05
# 2019-05-01            118.933333     99607.833333       9.051135e+05
# 2019-06-01              0.000000     -8646.333333      -4.178083e+04
# 2019-07-01              8.266667    254538.000000       3.349302e+06
#
#             ConsumServeis
# Fecha
# 2019-03-01   2.924123e+06
# 2019-04-01  -8.537917e+05
# 2019-05-01   1.118954e+06
# 2019-06-01  -5.736525e+05
# 2019-07-01   3.698937e+06

# %%
# Plot
fig, axes = plt.subplots(nrows=4, ncols=1, dpi=120, figsize=(12,6))
for i, ax in enumerate(axes.flatten()):
    data = X_train_transformed[X_train_transformed.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(X_train_transformed.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
print('Test de Dickey-Fuller Aumentado 2da vez:')
for i in range(len(X_train_transformed.columns)):
  print('Serie de tiempo transformada', 'Variable', X_train_transformed.columns[i])
  augmented_dickey_fuller_statistics(X_train_transformed.iloc[:,i])
# Out:
# Test de Dickey-Fuller Aumentado 2da vez:
# Serie de tiempo transformada Variable Compraventa_Unitario
# p-value: 0.000347
# Serie de tiempo transformada Variable ConsumIndustria
# p-value: 0.000000
# Serie de tiempo transformada Variable ConsumResidencial
# p-value: 0.000000
# Serie de tiempo transformada Variable ConsumServeis
# p-value: 0.000702

# %% [markdown]
# Todos los p-valores son < 0.05 por lo tanto se podría concluir que con 1 orden de diferenciación se obtienen series estacionarias.

# %%
from statsmodels.tsa.api import VAR

# %%
model = VAR(X_train_transformed)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# #### Seleccionando el orden del modelo

# %%
modelsel=model.select_order(6)
modelsel.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# #### Ajustando el modelo

# %%
res = model.fit(maxlags=6, ic='aic')
res.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 05, May, 2024
# Time:                     06:12:55
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    92.5966
# Nobs:                     40.0000    HQIC:                   89.9010
# Log likelihood:          -1894.52    FPE:                5.70618e+38
# AIC:                      88.3744    Det(Omega_mle):     8.18336e+37
# --------------------------------------------------------------------
# Results for equation Compraventa_Unitario
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -8.039831        30.718722           -0.262           0.794
# L1.Compraventa_Unitario        -0.714480         0.253155           -2.822           0.005
# L1.ConsumIndustria              0.000369         0.001133            0.326           0.745
# L1.ConsumResidencial           -0.000033         0.000034           -0.979           0.328
# L1.ConsumServeis               -0.000025         0.000042           -0.591           0.554
# L2.Compraventa_Unitario        -0.567682         0.300461           -1.889           0.059
# L2.ConsumIndustria              0.002058         0.001514            1.359           0.174
# L2.ConsumResidencial           -0.000127         0.000051           -2.518           0.012
# L2.ConsumServeis               -0.000057         0.000065           -0.867           0.386
# L3.Compraventa_Unitario        -0.362767         0.397842           -0.912           0.362
# L3.ConsumIndustria              0.001028         0.001822            0.564           0.573
# L3.ConsumResidencial           -0.000075         0.000062           -1.208           0.227
# L3.ConsumServeis               -0.000038         0.000072           -0.530           0.596
# L4.Compraventa_Unitario        -0.166878         0.404764           -0.412           0.680
# L4.ConsumIndustria              0.001817         0.001793            1.013           0.311
# L4.ConsumResidencial           -0.000125         0.000055           -2.264           0.024
# L4.ConsumServeis               -0.000055         0.000071           -0.781           0.435
# L5.Compraventa_Unitario         0.351156         0.337858            1.039           0.299
# L5.ConsumIndustria              0.002670         0.001679            1.590           0.112
# L5.ConsumResidencial           -0.000068         0.000055           -1.246           0.213
# L5.ConsumServeis               -0.000095         0.000064           -1.486           0.137
# L6.Compraventa_Unitario        -0.102544         0.327658           -0.313           0.754
# L6.ConsumIndustria              0.000096         0.001325            0.072           0.943
# L6.ConsumResidencial           -0.000025         0.000041           -0.600           0.549
# L6.ConsumServeis               -0.000014         0.000044           -0.315           0.752
# ==========================================================================================
#
# Results for equation ConsumIndustria
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                         244.126794     10243.593394            0.024           0.981
# L1.Compraventa_Unitario        52.162442        84.418105            0.618           0.537
# L1.ConsumIndustria             -0.973178         0.377905           -2.575           0.010
# L1.ConsumResidencial           -0.028275         0.011208           -2.523           0.012
# L1.ConsumServeis                0.003677         0.014019            0.262           0.793
# L2.Compraventa_Unitario       174.838244       100.192933            1.745           0.081
# L2.ConsumIndustria             -1.678832         0.504787           -3.326           0.001
# L2.ConsumResidencial           -0.012516         0.016865           -0.742           0.458
# L2.ConsumServeis                0.040380         0.021785            1.854           0.064
# L3.Compraventa_Unitario       120.192673       132.666112            0.906           0.365
# L3.ConsumIndustria             -1.778940         0.607724           -2.927           0.003
# L3.ConsumResidencial           -0.014815         0.020692           -0.716           0.474
# L3.ConsumServeis                0.040178         0.024042            1.671           0.095
# L4.Compraventa_Unitario        86.873876       134.974409            0.644           0.520
# L4.ConsumIndustria             -0.617636         0.597915           -1.033           0.302
# L4.ConsumResidencial           -0.015206         0.018382           -0.827           0.408
# L4.ConsumServeis               -0.012082         0.023595           -0.512           0.609
# L5.Compraventa_Unitario       237.648195       112.663595            2.109           0.035
# L5.ConsumIndustria             -0.327791         0.559809           -0.586           0.558
# L5.ConsumResidencial           -0.030268         0.018206           -1.663           0.096
# L5.ConsumServeis               -0.019104         0.021324           -0.896           0.370
# L6.Compraventa_Unitario       119.132230       109.262218            1.090           0.276
# L6.ConsumIndustria             -0.299770         0.441804           -0.679           0.497
# L6.ConsumResidencial           -0.004465         0.013640           -0.327           0.743
# L6.ConsumServeis               -0.006218         0.014794           -0.420           0.674
# ==========================================================================================
#
# Results for equation ConsumResidencial
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                      -14765.003187    207043.052891           -0.071           0.943
# L1.Compraventa_Unitario     -1365.572312      1706.254965           -0.800           0.424
# L1.ConsumIndustria             -2.934447         7.638206           -0.384           0.701
# L1.ConsumResidencial           -0.929921         0.226536           -4.105           0.000
# L1.ConsumServeis                0.038057         0.283359            0.134           0.893
# L2.Compraventa_Unitario        98.928343      2025.095095            0.049           0.961
# L2.ConsumIndustria             -8.855814        10.202737           -0.868           0.385
# L2.ConsumResidencial           -0.873524         0.340865           -2.563           0.010
# L2.ConsumServeis                0.151068         0.440325            0.343           0.732
# L3.Compraventa_Unitario      4898.579821      2681.441537            1.827           0.068
# L3.ConsumIndustria             -6.102504        12.283285           -0.497           0.619
# L3.ConsumResidencial           -0.870168         0.418216           -2.081           0.037
# L3.ConsumServeis                0.046741         0.485938            0.096           0.923
# L4.Compraventa_Unitario      5583.561396      2728.096745            2.047           0.041
# L4.ConsumIndustria             -8.717038        12.085028           -0.721           0.471
# L4.ConsumResidencial           -0.316844         0.371531           -0.853           0.394
# L4.ConsumServeis                0.040624         0.476896            0.085           0.932
# L5.Compraventa_Unitario      5760.059192      2277.151552            2.530           0.011
# L5.ConsumIndustria             -6.070726        11.314836           -0.537           0.592
# L5.ConsumResidencial           -0.234512         0.367971           -0.637           0.524
# L5.ConsumServeis                0.142704         0.431006            0.331           0.741
# L6.Compraventa_Unitario      4415.018703      2208.403082            1.999           0.046
# L6.ConsumIndustria              3.098407         8.929716            0.347           0.729
# L6.ConsumResidencial            0.143026         0.275687            0.519           0.604
# L6.ConsumServeis               -0.023537         0.299023           -0.079           0.937
# ==========================================================================================
#
# Results for equation ConsumServeis
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                       -8689.261141    211508.460065           -0.041           0.967
# L1.Compraventa_Unitario      2210.057452      1743.054670            1.268           0.205
# L1.ConsumIndustria              1.890992         7.802943            0.242           0.809
# L1.ConsumResidencial           -0.531926         0.231421           -2.299           0.022
# L1.ConsumServeis               -1.099907         0.289470           -3.800           0.000
# L2.Compraventa_Unitario      5310.376518      2068.771393            2.567           0.010
# L2.ConsumIndustria            -22.089855        10.422785           -2.119           0.034
# L2.ConsumResidencial           -0.150274         0.348216           -0.432           0.666
# L2.ConsumServeis                0.237790         0.449822            0.529           0.597
# L3.Compraventa_Unitario       570.883795      2739.273606            0.208           0.835
# L3.ConsumIndustria            -28.012250        12.548205           -2.232           0.026
# L3.ConsumResidencial           -0.357590         0.427236           -0.837           0.403
# L3.ConsumServeis                0.565794         0.496418            1.140           0.254
# L4.Compraventa_Unitario      -858.731282      2786.935052           -0.308           0.758
# L4.ConsumIndustria              7.520949        12.345672            0.609           0.542
# L4.ConsumResidencial           -0.477912         0.379544           -1.259           0.208
# L4.ConsumServeis               -1.052114         0.487181           -2.160           0.031
# L5.Compraventa_Unitario      3632.088715      2326.264086            1.561           0.118
# L5.ConsumIndustria             12.201066        11.558869            1.056           0.291
# L5.ConsumResidencial           -0.918678         0.375907           -2.444           0.015
# L5.ConsumServeis               -1.367866         0.440302           -3.107           0.002
# L6.Compraventa_Unitario      3413.280765      2256.032880            1.513           0.130
# L6.ConsumIndustria              5.606412         9.122308            0.615           0.539
# L6.ConsumResidencial           -0.377815         0.281633           -1.342           0.180
# L6.ConsumServeis               -0.733275         0.305472           -2.400           0.016
# ==========================================================================================
#
# Correlation matrix of residuals
#                         Compraventa_Unitario  ConsumIndustria  ConsumResidencial  ConsumServeis
# Compraventa_Unitario                1.000000        -0.138643           0.132192      -0.149680
# ConsumIndustria                    -0.138643         1.000000           0.343780       0.864852
# ConsumResidencial                   0.132192         0.343780           1.000000       0.311157
# ConsumServeis                      -0.149680         0.864852           0.311157       1.000000

# %%
X_train.columns
# Out:
# Index(['Compraventa_Unitario', 'ConsumIndustria', 'ConsumResidencial',
#        'ConsumServeis'],
#       dtype='object')

# %% [markdown]
# ###### Causalidad de Granger

# %%
grangercaus=res.test_causality(['ConsumIndustria', 'ConsumResidencial','ConsumServeis'],['Compraventa_Unitario'],kind='f')
grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
grangercaus=res.test_causality(['Compraventa_Unitario', 'ConsumResidencial','ConsumServeis'],['ConsumIndustria'],kind='f')
grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
grangercaus=res.test_causality(['Compraventa_Unitario', 'ConsumIndustria', 'ConsumServeis'],['ConsumResidencial'],kind='f')
grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
grangercaus=res.test_causality(['Compraventa_Unitario', 'ConsumIndustria','ConsumResidencial'],['ConsumServeis'],kind='f')
grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Como se puede observar, la causalidad de Granger nos indica que ninguna de las series temporales puede predecir la otra serie temporal

# %% [markdown]
# ###### Matriz de causalidad de Granger

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import grangercausalitytests
import warnings
warnings.filterwarnings("ignore")
maxlag=12
test = 'ssr_chi2test'
def grangers_causality_matrix(X_train_transformed, variables, test = 'ssr_chi2test', verbose=False):
  dataset = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
  for c in dataset.columns:
    for r in dataset.index:
      test_result = grangercausalitytests(X_train_transformed[[r,c]], maxlag=maxlag, verbose=False)
      p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
      if verbose:
        print(f'Y = {r}, X = {c}, P Values = {p_values}')
      min_p_value = np.min(p_values)
      dataset.loc[r,c] = min_p_value
  dataset.columns = [var + '_x' for var in variables]
  dataset.index = [var + '_y' for var in variables]
  return dataset
grangers_causality_matrix(X_train_transformed, variables = X_train_transformed.columns)
# Out:
#                         Compraventa_Unitario_x  ConsumIndustria_x  \
# Compraventa_Unitario_y                     1.0             0.0000
# ConsumIndustria_y                          0.0             1.0000
# ConsumResidencial_y                        0.0             0.0002
# ConsumServeis_y                            0.0             0.0000
#
#                         ConsumResidencial_x  ConsumServeis_x
# Compraventa_Unitario_y                  0.0              0.0
# ConsumIndustria_y                       0.0              0.0
# ConsumResidencial_y                     1.0              0.0
# ConsumServeis_y                         0.0              1.0

# %% [markdown]
# Con esta matriz queda claro que la serie temporal de Compraventa_Unitario no causa ni es causada por la otra serie temporal de ParadosReg

# %% [markdown]
# ###### Diagnosis del modelo

# %% [markdown]
# ###### Residuos

# %%
residuals=res.resid

# %%
fig, axs = plt.subplots(4)
fig.suptitle('Gráficos de los residuos',fontsize=20)
fig.set_size_inches(18, 10)
[axs[i].plot(residuals.iloc[:,i]) for i in range(4)]
plt.show()

# %% [markdown]
# ###### Dickey - Fuller a los residuos

# %%
print('ADF de los Residuos, p-valores:')
[sts.adfuller(residuals.iloc[:,i])[1] for i in range(4)]
# Out:
# ADF de los Residuos, p-valores:
# [1.6133103975227562e-07,
#  0.00010492598101117203,
#  6.367775308193266e-05,
#  3.511500864022463e-06]

# %% [markdown]
# Todos los p-valores son < 0.1 por tanto se rechaza la hipótesis nula de que las 2 series de residuos no son estacionarias, por lo cual con un 90% de confianza se cree que son estacionarias.

# %% [markdown]
# ###### ACF de los Residuos

# %%
import statsmodels.graphics.tsaplots as sgt
[sgt.plot_acf(residuals.iloc[:,i], zero = False, lags = 12) for i in range(4)]
plt.show()

# %% [markdown]
# Conclusión: Los residuos del modelo no presentan estructura de autocorrelación, son estacionarios según los resultados de la prueba de Dickey - Fuller aumentada y en los gráficos se puede comprobar esto visualmente, entonces puede concluirse que son ruido blanco como es deseable.

# %% [markdown]
# #### Valores predichos

# %%
y_fitted = res.fittedvalues
fig, axs = plt.subplots(4)
fig.suptitle('Gráficos de los valores predichos por el modelo',fontsize=15)
fig.set_size_inches(18, 10)
[axs[i].plot(y_fitted.iloc[:,i]) for i in range(4)]
plt.show()

# %% [markdown]
# #### Pronósticos a futuro

# %% [markdown]
# Para pronosticar, al modelo VAR le podemos pasar hasta el número de orden de retraso de observaciones de los datos pasados. Esto se debe a que los términos en el modelo VAR son esencialmente los retrasos de las diversas series de tiempo en el conjunto de datos, por lo que debemos proporcionar tantos valores anteriores como lo indique el orden de retraso utilizado por el modelo. De lo contrario estaríamos introduciendo poca fiabilidad.

# %%
# Obtener el orden del modelo
lag_order = res.k_ar
print('Orden del modelo:', lag_order)
# Input data para hacer forecasting (pronósticos a futuro)
input_data = X_train_transformed.values[-lag_order:]
# Forecasting
pred = res.forecast(y=input_data, steps=9)
pred = (pd.DataFrame(pred, index=X_test.index, columns=X_test.columns + '_pred'))
print('Predicciones:')
pred
# Out:
# Orden del modelo: 6
# Predicciones:
#             Compraventa_Unitario_pred  ConsumIndustria_pred  \
# Fecha
# 2023-01-01                -415.216051          37163.193564
# 2023-02-01                 208.620940         -37946.918534
# 2023-03-01                 -59.943212         -83531.978650
# 2023-04-01                 604.613021         -61310.800220
# 2023-05-01                -504.772992          63024.449276
# 2023-06-01                   5.246680         206533.736814
# 2023-07-01                  19.146030        -112520.354350
# 2023-08-01                 -27.894550         -93195.934436
# 2023-09-01                 113.728070         108494.847350
#
#             ConsumResidencial_pred  ConsumServeis_pred
# Fecha
# 2023-01-01           -4.975747e+06        3.321842e+06
# 2023-02-01            6.877231e+05       -5.859138e+06
# 2023-03-01            2.672223e+06        1.511636e+06
# 2023-04-01           -3.138445e+06       -1.773589e+06
# 2023-05-01            2.789290e+06        1.067789e+06
# 2023-06-01           -5.665523e+05        5.233371e+06
# 2023-07-01            7.336504e+05       -4.649590e+06
# 2023-08-01           -7.241242e+05        5.490781e+04
# 2023-09-01            8.295283e+04        1.247924e+06

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12, 10))
res.plot_forecast(lag_order)
plt.tight_layout(h_pad = 1.15)
plt.show()

# %% [markdown]
# #### Invirtiendo la transformación de los pronósticos a la escala original

# %% [markdown]
# Los pronósticos se generan en la escala de los datos de entrenamiento utilizados por el modelo, es decir, son datos transformados. Entonces, para volver a ponerlos en su escala original, necesitamos des-diferenciarlos. La forma de invertir la diferenciación es sumar estas diferencias consecutivamente al número base. Una forma sencilla de hacerlo es determinar primero la suma acumulada y luego sumarla al número base. Este proceso se puede revertir agregando la observación en el paso de tiempo anterior al difference value. inverted(ts) = differenced(ts) + observation(ts-1)

# %%
# Invirtiendo la transformación teniendo en cuenta que hemos diferenciado dos veces
def invert_transformation(ds, df_forecast, second_diff=False):
    for col in ds.columns:
        # Undo the 2nd Differencing
        if second_diff:
            df_forecast[str(col)] = (ds[col].iloc[-1] - ds[col].iloc[-2]) + df_forecast[str(col)].cumsum()

        # Undo the 1st Differencing
        df_forecast[str(col)] = ds[col].iloc[-1] + df_forecast[str(col)].cumsum()

    return df_forecast

# %%
pred.columns=X_test.columns
output = invert_transformation(X_train, pred, second_diff=True)
output
# Out:
#             Compraventa_Unitario  ConsumIndustria  ConsumResidencial  \
# Fecha
# 2023-01-01           5014.767282    822593.360231       1.029835e+07
# 2023-02-01           4808.172172    870440.635261       8.273658e+06
# 2023-03-01           4541.633849    834755.931641       8.921184e+06
# 2023-04-01           4879.708547    737760.427801       6.430266e+06
# 2023-05-01           4713.010253    703789.373238       6.728638e+06
# 2023-06-01           4551.558639    876352.055488       6.460457e+06
# 2023-07-01           4409.253055    936394.383389       6.925926e+06
# 2023-08-01           4239.052921    903240.776854       6.667271e+06
# 2023-09-01           4182.580858    978582.017669       6.491569e+06
#
#             ConsumServeis
# Fecha
# 2023-01-01   2.181773e+07
# 2023-02-01   2.030043e+07
# 2023-03-01   2.029477e+07
# 2023-04-01   1.851551e+07
# 2023-05-01   1.780405e+07
# 2023-06-01   2.232596e+07
# 2023-07-01   2.219828e+07
# 2023-08-01   2.212551e+07
# 2023-09-01   2.330066e+07

# %%
# Actual vs Forecasted Plots
fig, axes = plt.subplots(nrows = int(len(X_train.columns)), ncols = 1, dpi = 100, figsize = (14,10))
mi_lista = ['€/m²', 'KW/h','KW/h', 'KW/h']

for i, (col,ax) in enumerate(zip(X_train.columns, axes.flatten())):
    output[col].plot(color = '#00FF00', legend = True, ax = ax).autoscale(axis =' x',tight = True)
    X_test[col].plot(color = '#F4511E', legend = True, ax = ax)
    X_train[col].plot(color = '#3949AB', legend = True, ax = ax)

    ax.set_title('Variable: ' + col + ' - Actual vs Forecast')
    ax.set_ylabel(mi_lista[i])  # Establecer etiqueta del eje y
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')

    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize = 6)

plt.tight_layout()
plt.savefig('actual_forecast.png')
plt.show()

# %% [markdown]
# #### Evaluando el modelo

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):

    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
for i in ['Compraventa_Unitario','ConsumIndustria', 'ConsumResidencial','ConsumServeis']:
    print(f'Evaluation metric for {i}')
    timeseries_evaluation_metrics_func(X_test[str(i)] , output[str(i)])
# Out:
# Evaluation metric for Compraventa_Unitario
# Evaluation metric results:-
# MSE is : 1321990.216998641
# MAE is : 995.7291583392899
# RMSE is : 1149.778333853374
# MAPE is : 17.308949973119642
# R2 is : -11.011819173361722
#
# Evaluation metric for ConsumIndustria
# Evaluation metric results:-
# MSE is : 113173161681.74075
# MAE is : 260347.91278843457
# RMSE is : 336412.19015032845
# MAPE is : 62.036492744553776
# R2 is : -2.382666513223587
#
# Evaluation metric for ConsumResidencial
# Evaluation metric results:-
# MSE is : 17382494141428.352
# MAE is : 3982137.9451627084
# RMSE is : 4169231.8406906025
# MAPE is : 34.657092485216026
# R2 is : -9.749613396175404
#
# Evaluation metric for ConsumServeis
# Evaluation metric results:-
# MSE is : 29786835382977.48
# MAE is : 4293047.388176625
# RMSE is : 5457731.706760372
# MAPE is : 31.858382610115843
# R2 is : -0.4658143959736054

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print('Mean absolute error:', mean_absolute_error(X_test, output))
print('Root mean squared error:', np.sqrt(mean_squared_error(X_test, output)))
# Out:
# Mean absolute error: 2134132.243821527
# Root mean squared error: 3438113.7273248318

# %% [markdown]
# ### Modelo VARMAX (Auto Arima)

# %% [markdown]
# El modelo VARMAX es una extension del modelo VAR que permite incorporar variebles exogenas, es decir, varibales externas que pueden afectar a las series temporales del sistema, es decir, que ademas de modelar la dependencia entre las variables del sistema, el VARMAX tambien puede capturar la influencia de variables externas sobre las series temporales.

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.4.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.10)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.25.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (67.7.2)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4

# %% [markdown]
# #### Dividir los datos en conjuntos de Entrenamiento Y Prueba

# %%
fecha_division = '2023-01-01'

X_train, X_test = df[df.index<fecha_division], df[df.index>=fecha_division]
print(X_train.shape, X_test.shape)
# Out:
# (48, 4) (9, 4)

# %% [markdown]
# #### Prueba de estacionariedad

# %% [markdown]
# Necesitamos que los datos sean estacionarios para poder usar el modelo VAR. Vamos a averiguarlo haciendo un Test de Dickey-Fuller aumentado, a cada variable univariante que tiene nuestro dataset.

# %%
def augmented_dickey_fuller_statistics(time_series):
  result = sts.adfuller(time_series.values)
  print('p-value: %f' % result[1])

print('Test de Dickey-Fuller Aumentado:')
for i in range(len(X_train.columns)):
  print('Serie de tiempo',X_train.columns[i])
  augmented_dickey_fuller_statistics(X_train.iloc[:,i])
# Out:
# Test de Dickey-Fuller Aumentado:
# Serie de tiempo Compraventa_Unitario
# p-value: 0.333200
# Serie de tiempo ConsumIndustria
# p-value: 0.049484
# Serie de tiempo ConsumResidencial
# p-value: 0.000001
# Serie de tiempo ConsumServeis
# p-value: 0.057989

# %% [markdown]
# Los p-valores son mayores que 0.05, con lo cual no se rechaza la hipótesis nula de que la serie no es estacionaria. Habría que transformar los datos porque no se puede confirmar estacionariedad.

# %%
#Diferenciando por primera vez
X_train_transformed=X_train.diff().dropna()
X_train_transformed.head()
# Out:
#             Compraventa_Unitario  ConsumIndustria  ConsumResidencial  \
# Fecha
# 2019-02-01              0.000000   -141620.333333      -3.097110e+06
# 2019-03-01              0.000000     18725.000000      -4.351532e+05
# 2019-04-01           -118.933333    -56757.833333      -1.065591e+06
# 2019-05-01              0.000000     42850.000000      -1.604777e+05
# 2019-06-01              0.000000     34203.666667      -2.022585e+05
#
#             ConsumServeis
# Fecha
# 2019-02-01  -2.360303e+06
# 2019-03-01   5.638198e+05
# 2019-04-01  -2.899718e+05
# 2019-05-01   8.289825e+05
# 2019-06-01   2.553300e+05

# %%
print('Test de Dickey-Fuller Aumentado 2da vez:')
for i in range(len(X_train_transformed.columns)):
  print('Serie de tiempo transformada', 'Variable', X_train_transformed.columns[i])
  augmented_dickey_fuller_statistics(X_train_transformed.iloc[:,i])
# Out:
# Test de Dickey-Fuller Aumentado 2da vez:
# Serie de tiempo transformada Variable Compraventa_Unitario
# p-value: 0.000410
# Serie de tiempo transformada Variable ConsumIndustria
# p-value: 0.055907
# Serie de tiempo transformada Variable ConsumResidencial
# p-value: 0.000000
# Serie de tiempo transformada Variable ConsumServeis
# p-value: 0.004797

# %%
#Diferenciando por segunda vez
X_train_transformed=X_train.diff().diff().dropna()
X_train_transformed.head()
# Out:
#             Compraventa_Unitario  ConsumIndustria  ConsumResidencial  \
# Fecha
# 2019-03-01              0.000000    160345.333333       2.661956e+06
# 2019-04-01           -118.933333    -75482.833333      -6.304380e+05
# 2019-05-01            118.933333     99607.833333       9.051135e+05
# 2019-06-01              0.000000     -8646.333333      -4.178083e+04
# 2019-07-01              8.266667    254538.000000       3.349302e+06
#
#             ConsumServeis
# Fecha
# 2019-03-01   2.924123e+06
# 2019-04-01  -8.537917e+05
# 2019-05-01   1.118954e+06
# 2019-06-01  -5.736525e+05
# 2019-07-01   3.698937e+06

# %%
print('Test de Dickey-Fuller Aumentado 2da vez:')
for i in range(len(X_train_transformed.columns)):
  print('Serie de tiempo transformada', 'Variable', X_train_transformed.columns[i])
  augmented_dickey_fuller_statistics(X_train_transformed.iloc[:,i])
# Out:
# Test de Dickey-Fuller Aumentado 2da vez:
# Serie de tiempo transformada Variable Compraventa_Unitario
# p-value: 0.000347
# Serie de tiempo transformada Variable ConsumIndustria
# p-value: 0.000000
# Serie de tiempo transformada Variable ConsumResidencial
# p-value: 0.000000
# Serie de tiempo transformada Variable ConsumServeis
# p-value: 0.000702

# %% [markdown]
# Todos los p-valores son < 0.05 por lo tanto se podría concluir que con 1 orden de diferenciación se obtienen series estacionarias.

# %% [markdown]
# ####Test de Cointegracion

# %% [markdown]
# Determinaremos si las dos variables estan relacionadas entre si y si esa relacion es duradera o no

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df):
    res = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = res.lr1
    cvts = res.cvt[:, d[str(1-0.05)]]
    def adjust(val, length= 6):
        return str(val).ljust(length)
    print('Column Name   >  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), '> ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

# %%
cointegration_test(X_train_transformed[['Compraventa_Unitario','ConsumIndustria', 'ConsumResidencial','ConsumServeis']])
# Out:
# Column Name   >  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# Compraventa_Unitario >  150.23    > 40.1749   =>   True
# ConsumIndustria >  73.93     > 24.2761   =>   True
# ConsumResidencial >  40.16     > 12.3212   =>   True
# ConsumServeis >  15.21     > 4.1296    =>   True

# %% [markdown]
# El test es satisfactorio

# %% [markdown]
# #### Ajustando el modelo

# %% [markdown]
# #####Auto Arima

# %% [markdown]
# Aplicaremos autoarima, para determinar los valores de p, q y d

# %%
import pmdarima as pm

# %%
pq = []
for name in ['Compraventa_Unitario', 'ConsumIndustria', 'ConsumResidencial','ConsumServeis']:
    print(f'Searching order of p and q for : {name}')
    # Ajusta un modelo ARIMA para cada columna
    stepwise_model = pm.auto_arima(X_train_transformed[name],
                                start_p=0, start_q=0,
                                max_p=4, max_q=4,
                                seasonal=False,
                                trace=True,
                                error_action='ignore',
                                suppress_warnings=True,
                                stepwise=True,
                                maxiter=1000)
    # Obtiene los parámetros óptimos de p y q del modelo
    parameter = stepwise_model.get_params().get('order')
    print(f'optimal order for:{name} is: {parameter} \n\n')
    # Agrega los parámetros óptimos a la lista pq
    pq.append(stepwise_model.get_params().get('order'))
# Out:
# Searching order of p and q for : Compraventa_Unitario
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=645.492, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=634.539, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=633.574, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=630.894, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=630.432, Time=0.10 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=632.401, Time=0.12 sec
#
# Best model:  ARIMA(4,0,0)(0,0,0)[0]
# Total fit time: 0.771 seconds
# optimal order for:Compraventa_Unitario is: (4, 0, 0)
#
#
# Searching order of p and q for : ConsumIndustria
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1253.405, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1227.479, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1219.500, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1215.084, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1215.279, Time=0.11 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.30 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1216.085, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1227.993, Time=0.03 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.36 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1217.025, Time=0.05 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.035 seconds
# optimal order for:ConsumIndustria is: (1, 0, 1)
#
#
# Searching order of p and q for : ConsumResidencial
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1489.543, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1469.706, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1459.263, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1458.819, Time=0.07 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1460.271, Time=0.10 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1458.736, Time=0.06 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1464.527, Time=0.06 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1455.155, Time=0.16 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=1455.884, Time=0.24 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=1454.427, Time=0.15 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1464.725, Time=0.10 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=1453.055, Time=0.28 sec
#  ARIMA(3,0,4)(0,0,0)[0]             : AIC=1450.746, Time=1.21 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=1455.808, Time=0.29 sec
#  ARIMA(4,0,4)(0,0,0)[0]             : AIC=1450.703, Time=1.10 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=1457.633, Time=0.25 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=1452.539, Time=2.36 sec
#
# Best model:  ARIMA(4,0,4)(0,0,0)[0]
# Total fit time: 6.649 seconds
# optimal order for:ConsumResidencial is: (4, 0, 4)
#
#
# Searching order of p and q for : ConsumServeis
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1546.648, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1511.837, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1508.532, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1497.215, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1499.081, Time=0.12 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1498.744, Time=0.21 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1503.049, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1508.278, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.25 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1500.286, Time=0.10 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.128 seconds
# optimal order for:ConsumServeis is: (1, 0, 1)

# %% [markdown]
# #####Seleccion del modelo

# %%
def inverse_diff(actual_df, pred_df, second_diff=False):
    df_res = pred_df.copy()
    columns = actual_df.columns
    for col in columns:
        if second_diff:
          df_res[str(col)] = (actual_df[col].iloc[-1]- actual_df[col].iloc[-2]) + df_res[str(col)].cumsum()

        df_res[str(col)] = actual_df[col].iloc[-1] + df_res[str(col)].cumsum()
    return df_res

# %%
pq
# Out:
# [(4, 0, 0), (1, 0, 1), (4, 0, 4), (1, 0, 1)]

# %%
from statsmodels.tsa.statespace.varmax import VARMAX

# %%
df_results_moni = pd.DataFrame(columns=['p', 'q','RMSE Compraventa_Unitario','RMSE ConsumIndustria','RMSE ConsumResidencial','RMSE ConsumServeis'])
print('Grid Search Started')
for i in pq:
    if i[0]== 0 and i[2] ==0:
        pass
    else:
        print(f' Running for {i}')
        model = VARMAX(X_train_transformed[['Compraventa_Unitario', 'ConsumIndustria', 'ConsumResidencial','ConsumServeis']], order=(i[0],i[2])).fit( disp=False)
        result = model.forecast(steps = 9)
        inv_res = inverse_diff(df[['Compraventa_Unitario',  'ConsumIndustria', 'ConsumResidencial','ConsumServeis']] , result, True)
        Comprarmse = np.sqrt(metrics.mean_squared_error(X_test['Compraventa_Unitario'], inv_res.Compraventa_Unitario))
        Paradosrmse = np.sqrt(metrics.mean_squared_error(X_test['ConsumIndustria'], inv_res.ConsumIndustria))
        Pmrmse = np.sqrt(metrics.mean_squared_error(X_test['ConsumResidencial'], inv_res.ConsumResidencial))
        Bachrmse = np.sqrt(metrics.mean_squared_error(X_test['ConsumServeis'], inv_res.ConsumServeis))
        #df_results_moni = df_results_moni.append({'p': i[0], 'q': i[2], 'RMSE Compraventa_Unitario':Comprarmse,'RMSE ParadosReg':Paradosrmse }, ignore_index=False)
        df_results_moni.loc[len(df_results_moni)] = [i[0], i[2], Comprarmse, Paradosrmse,Pmrmse,Bachrmse]
# Out:
# Grid Search Started
#  Running for (4, 0, 0)
#  Running for (1, 0, 1)
#  Running for (4, 0, 4)
#  Running for (1, 0, 1)

# %%
df_results_moni.sort_values(by = ['RMSE Compraventa_Unitario','RMSE ConsumIndustria','RMSE ConsumResidencial','RMSE ConsumServeis'] )
# Out:
#      p    q  RMSE Compraventa_Unitario  RMSE ConsumIndustria  \
# 2  4.0  4.0                 570.894308         568721.854640
# 1  1.0  1.0                 727.163970         585763.299871
# 3  1.0  1.0                 727.163970         585763.299871
# 0  4.0  0.0                1241.424827         800258.933840
#
#    RMSE ConsumResidencial  RMSE ConsumServeis
# 2            3.429167e+06        3.853944e+07
# 1            2.254777e+06        3.467092e+07
# 3            2.254777e+06        3.467092e+07
# 0            2.021766e+06        4.203512e+07

# %% [markdown]
# #### Pronósticos a futuro

# %%
model = VARMAX(X_train_transformed[['Compraventa_Unitario','ConsumIndustria', 'ConsumResidencial','ConsumServeis']], order=(0,2)).fit(disp=False)
result = model.forecast(steps = 9)

# %%
result
# Out:
#             Compraventa_Unitario  ConsumIndustria  ConsumResidencial  \
# 2023-01-01            -98.627468   -121050.378912      -1.589160e+06
# 2023-02-01           -103.532654      2223.366023      -3.480958e+05
# 2023-03-01              0.003445      4135.898561       1.165312e+05
# 2023-04-01              0.003445      4135.898561       1.165312e+05
# 2023-05-01              0.003445      4135.898561       1.165312e+05
# 2023-06-01              0.003445      4135.898561       1.165312e+05
# 2023-07-01              0.003445      4135.898561       1.165312e+05
# 2023-08-01              0.003445      4135.898561       1.165312e+05
# 2023-09-01              0.003445      4135.898561       1.165312e+05
#
#             ConsumServeis
# 2023-01-01  -3.500125e+06
# 2023-02-01  -7.020856e+05
# 2023-03-01   7.348480e+04
# 2023-04-01   7.348480e+04
# 2023-05-01   7.348480e+04
# 2023-06-01   7.348480e+04
# 2023-07-01   7.348480e+04
# 2023-08-01   7.348480e+04
# 2023-09-01   7.348480e+04

# %% [markdown]
# #### Invertiendo la transformacion de los pronosticos a la escala original

# %%
res = inverse_diff(df[['Compraventa_Unitario', 'ConsumIndustria', 'ConsumResidencial','ConsumServeis']],result,False)

# %%
res
# Out:
#             Compraventa_Unitario  ConsumIndustria  ConsumResidencial  \
# 2023-01-01           5959.455865    304727.121088       9.879077e+06
# 2023-02-01           5855.923211    306950.487111       9.530981e+06
# 2023-03-01           5855.926656    311086.385672       9.647512e+06
# 2023-04-01           5855.930100    315222.284234       9.764044e+06
# 2023-05-01           5855.933545    319358.182795       9.880575e+06
# 2023-06-01           5855.936989    323494.081356       9.997106e+06
# 2023-07-01           5855.940434    327629.979918       1.011364e+07
# 2023-08-01           5855.943879    331765.878479       1.023017e+07
# 2023-09-01           5855.947323    335901.777040       1.034670e+07
#
#             ConsumServeis
# 2023-01-01   2.100899e+07
# 2023-02-01   2.030690e+07
# 2023-03-01   2.038039e+07
# 2023-04-01   2.045387e+07
# 2023-05-01   2.052736e+07
# 2023-06-01   2.060084e+07
# 2023-07-01   2.067433e+07
# 2023-08-01   2.074781e+07
# 2023-09-01   2.082130e+07

# %%
# Actual vs Forecasted Plots
fig, axes = plt.subplots(nrows = int(len(X_train.columns)), ncols = 1, dpi = 100, figsize = (14,10))
mi_lista = ['€/m²', 'KW/h','KW/h', 'KW/h']

for i, (col,ax) in enumerate(zip(X_train.columns, axes.flatten())):
    res[col].plot(color = '#00FF00', legend = True, ax = ax).autoscale(axis =' x',tight = True)
    X_test[col].plot(color = '#F4511E', legend = True, ax = ax)
    X_train[col].plot(color = '#3949AB', legend = True, ax = ax)

    ax.set_title('Variable: ' + col + ' - Actual vs Forecast')
    ax.set_ylabel(mi_lista[i])  # Establecer etiqueta del eje y
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')

    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize = 6)

plt.tight_layout()
plt.savefig('actual_forecast.png')
plt.show()

# %% [markdown]
# #### Evaluando el modelo

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):

    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
for i in ['Compraventa_Unitario','ConsumIndustria', 'ConsumResidencial','ConsumServeis']:
    print(f'Evaluation metric for {i}')
    timeseries_evaluation_metrics_func(X_test[str(i)] , res[str(i)])
# Out:
# Evaluation metric for Compraventa_Unitario
# Evaluation metric results:-
# MSE is : 193809.84223113392
# MAE is : 413.1638589906805
# RMSE is : 440.2383925001702
# MAPE is : 7.569886541516861
# R2 is : -0.7609879021521824
#
# Evaluation metric for ConsumIndustria
# Evaluation metric results:-
# MSE is : 107541864277.36829
# MAE is : 281037.9532517649
# RMSE is : 327935.7624251559
# MAPE is : 42.85894488423991
# R2 is : -2.2143509791101055
#
# Evaluation metric for ConsumResidencial
# Evaluation metric results:-
# MSE is : 3907140819205.384
# MAE is : 1607632.6453833082
# RMSE is : 1976648.886172095
# MAPE is : 13.193124473276912
# R2 is : -1.4162385989691293
#
# Evaluation metric for ConsumServeis
# Evaluation metric results:-
# MSE is : 31299350165758.77
# MAE is : 4831438.067511078
# RMSE is : 5594582.215479434
# MAPE is : 34.36093768818665
# R2 is : -0.5402454630614073

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print('Mean absolute error:', mean_absolute_error(X_test, res))
print('Root mean squared error:', np.sqrt(mean_squared_error(X_test, res)))
# Out:
# Mean absolute error: 1680130.4575012855
# Root mean squared error: 2971280.5759071023

# %% [markdown]
# ##Conclusiones

# %% [markdown]
# Como conclusiones de realizar un analisis de datos forecasting a los datos de distrito de **Sarrià-Sant Gervasi** de Barcelona entre las tres series temporales de Compraventa_Unitario, Consumo electrico industrial, residencial y servicios, tenemos que:
#
# - Tal y como se ha comprobado las variables de consumo tiene correlacion, mientras que la Compraventa_Unitario no
#
# - **MODELO VAR**
#
#   - El numero de ordenes se ha establecido en 6.
#   - Tambien hemos comprobado por el concepto de causalidad de Granger como ninguna serie temporal puede predecir las demas series temporales
#   - Los resultados obtenidos no se ajustan a los datos de test
#
#
# - **MODELO VARMAX**
#   - Al implementar autoarima, nos ahorra mucho tiempo de analisis y configura los parámetros con los valores optimos
#   - El test de cointegracion nos ha dado positivo, lo que significa que las series estan relacionadas en el tiempo
#   - Los resultados obtenidos con este modelo se ajustan bastante bien a los datos de test
#
# - Si hacemos caso a las evaluaciones de los modelos, el segundo modelo tiene mejores ajustes
