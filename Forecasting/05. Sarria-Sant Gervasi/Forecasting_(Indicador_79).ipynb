# %% [markdown]
# <a href="https://colab.research.google.com/github/dmunozbe/TFM_DataScience/blob/main/Forecasting/05.%20Sarria-Sant%20Gervasi/Forecasting_(Indicador_79).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Forecasting**

# %% [markdown]
# **Forecasting** es el proceso de predecir eventos futuros basados en patrones históricos y datos existentes.
#
# El objetivo principal es el de hacer predicciones precisas sobre el futuro utilizando datos pasados y presentes y se utiliza en una amplia variaedad de constextos, como en finanzas, meteorologia, ventas entre otros
#
# Se realizaran comprobaciones de cointegracion, estacionariedad, para determinar que modelo aplicar entre los seleccionados:
#
# * Modelos VAR (Vector Autoregressive)
# * Modelos VARMA (Vector Autoregressive Moving Average)
# * Modelos VARMAx (VARMA con Variables Exógenas)
# * Modelos VECM (Vector Error Correlation Model)

# %% [markdown]
# ##Importar bibliotecas

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn import metrics


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##Carga de datos

# %%
# Cargar datos
data = pd.read_csv('/content/drive/MyDrive/UOC/TFM/Datasets definitivos/Final.csv')
data.head()
# Out:
#     Any  Trimestre  Mes  Codi_Districte Nom_Districte  Codi_Barri Nom_Barri  \
# 0  2014          1    1               1  Ciutat Vella           1  el Raval
# 1  2014          1    2               1  Ciutat Vella           1  el Raval
# 2  2014          1    3               1  Ciutat Vella           1  el Raval
# 3  2014          2    4               1  Ciutat Vella           1  el Raval
# 4  2014          2    5               1  Ciutat Vella           1  el Raval
#
#    Compraventa_Unitario  ParadosReg  Estudios_Obligatorios  ConsumResidencial  \
# 0                2813.0        4588                    NaN                NaN
# 1                2813.0        4539                    NaN                NaN
# 2                2813.0        4572                    NaN                NaN
# 3                2948.8        4510                    NaN                NaN
# 4                2948.8        4379                    NaN                NaN
#
#    Pm25  Pm10  Participacion  AñosEspVida  Internet  Movil  Index_Turisme  \
# 0   NaN   NaN           41.8         80.7       NaN    NaN            NaN
# 1   NaN   NaN           41.8         80.7       NaN    NaN            NaN
# 2   NaN   NaN           41.8         80.7       NaN    NaN            NaN
# 3   NaN   NaN           41.8         80.7       NaN    NaN            NaN
# 4   NaN   NaN           41.8         80.7       NaN    NaN            NaN
#
#    m² por habitante
# 0               6.2
# 1               6.2
# 2               6.2
# 3               6.2
# 4               6.2

# %%
print(data.dtypes)
# Out:
# Any                        int64
# Trimestre                  int64
# Mes                        int64
# Codi_Districte             int64
# Nom_Districte             object
# Codi_Barri                 int64
# Nom_Barri                 object
# Compraventa_Unitario     float64
# ParadosReg                 int64
# Estudios_Obligatorios    float64
# ConsumResidencial        float64
# Pm25                     float64
# Pm10                     float64
# Participacion            float64
# AñosEspVida              float64
# Internet                 float64
# Movil                    float64
# Index_Turisme            float64
# m² por habitante         float64
# dtype: object

# %% [markdown]
# ## Analisis por grupo de indicadores (Motorizacion Turismos)

# %% [markdown]
# ### Preparacion de datos

# %%
df_sel = data[['Any','Trimestre','Mes','Codi_Districte','Nom_Districte','Codi_Barri','Nom_Barri','Compraventa_Unitario','Index_Turisme']]

# %%
df_cont = df_sel.dropna()

# %%
df_cont.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2628 entries, 4380 to 7007
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Any                   2628 non-null   int64
#  1   Trimestre             2628 non-null   int64
#  2   Mes                   2628 non-null   int64
#  3   Codi_Districte        2628 non-null   int64
#  4   Nom_Districte         2628 non-null   object
#  5   Codi_Barri            2628 non-null   int64
#  6   Nom_Barri             2628 non-null   object
#  7   Compraventa_Unitario  2628 non-null   float64
#  8   Index_Turisme         2628 non-null   float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 205.3+ KB

# %%
# Creamos la variable de fecha de la siguiente manera:
# Agregar un día fijo para cada mes, por ejemplo, el día 1
df_cont['Fecha'] = pd.to_datetime(df_cont['Any'].astype(str) + '-' + df_cont['Mes'].astype(str) + '-1')

# %%
# Modificamos el indice del dataset por la fecha
df_contI = df_cont.set_index('Fecha')

# %%
df_contI.head()
# Out:
#              Any  Trimestre  Mes  Codi_Districte Nom_Districte  Codi_Barri  \
# Fecha
# 2019-01-01  2019          1    1               1  Ciutat Vella           1
# 2019-02-01  2019          1    2               1  Ciutat Vella           1
# 2019-03-01  2019          1    3               1  Ciutat Vella           1
# 2019-04-01  2019          2    4               1  Ciutat Vella           1
# 2019-05-01  2019          2    5               1  Ciutat Vella           1
#
#            Nom_Barri  Compraventa_Unitario  Index_Turisme
# Fecha
# 2019-01-01  el Raval                3775.1     122.718571
# 2019-02-01  el Raval                3775.1     122.718571
# 2019-03-01  el Raval                3775.1     122.718571
# 2019-04-01  el Raval                3838.4     122.718571
# 2019-05-01  el Raval                3838.4     122.718571

# %% [markdown]
# ### Analisis Exploratorio

# %% [markdown]
# Filtramos los datos por el distrito de Sarria-Sant Gervasi -> Codi_Districte = 5

# %%
df_contFiltrado = df_contI[df_contI['Codi_Districte'] == 5]

# %%
# Agrupamos los datos
df =df_contFiltrado.drop(columns=['Any','Trimestre','Mes','Codi_Districte','Nom_Districte','Codi_Barri','Nom_Barri']).groupby('Fecha').mean()

# %%
df.head()
# Out:
#             Compraventa_Unitario  Index_Turisme
# Fecha
# 2019-01-01           5455.166667     402.322695
# 2019-02-01           5455.166667     402.322695
# 2019-03-01           5455.166667     402.322695
# 2019-04-01           5336.233333     402.322695
# 2019-05-01           5336.233333     402.322695

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 36 entries, 2019-01-01 to 2021-12-01
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Compraventa_Unitario  36 non-null     float64
#  1   Index_Turisme         36 non-null     float64
# dtypes: float64(2)
# memory usage: 864.0 bytes

# %%
fig, axes = plt.subplots(nrows = int(len(df.columns)), ncols = 1, dpi = 100, figsize = (14,10))
unidades = ['€/m²', '% Turismes' ]
colores = ['#FF5733', '#3498DB']

for i, (col,ax) in enumerate(zip(df.columns, axes.flatten())):
    df[col].plot(color = colores[i], legend = True, ax = ax)
    ax.set_ylabel(unidades[i])  # Establecer etiqueta del eje y
plt.show()

# %% [markdown]
# Cada una de las series tiene patrones de tendencia muy diferentes entre si

# %%
corr=df.corr()
corr
# Out:
#                       Compraventa_Unitario  Index_Turisme
# Compraventa_Unitario               1.00000       -0.17967
# Index_Turisme                     -0.17967        1.00000

# %%
import seaborn as sb
fig, ax = plt.subplots(figsize=(12, 10))

sb.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values, annot=True,vmax=1, vmin=-1, cmap =sb.diverging_palette(220, 10, as_cmap=True),center=0,ax=ax )
plt.show()

# %% [markdown]
# La correlación entre "Compraventa_Unitario" e "Index_Turisme" es de -0.17967, lo que sugiere una correlación negativa débil entre estas dos variables en tus datos.

# %% [markdown]
# ### Dividir los datos en conjunto de Entrenamiento y Prueba

# %%
fecha_division = '2021-07-01'

X_train, X_test = df[df.index<fecha_division], df[df.index>=fecha_division]
print(X_train.shape, X_test.shape)
# Out:
# (30, 2) (6, 2)

# %% [markdown]
# Los modelos siguientes se ajustarán al conjunto de entrenamiento X_train y luego se utilizará el modelo para pronosticar las observaciones futuras. Estos pronósticos se compararán con los datos reales del conjunto de prueba.

# %% [markdown]
# ###Test de Cointegracion

# %% [markdown]
# Determinaremos si las dos variables estan relacionadas entre si y si esa relacion es duradera o no

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df):
    res = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = res.lr1
    cvts = res.cvt[:, d[str(1-0.05)]]
    def adjust(val, length= 6):
        return str(val).ljust(length)
    print('Column Name   >  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), '> ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

# %%
cointegration_test(X_train[['Compraventa_Unitario','Index_Turisme']])
# Out:
# Column Name   >  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# Compraventa_Unitario >  14.28     > 12.3212   =>   True
# Index_Turisme >  1.75      > 4.1296    =>   False

# %% [markdown]
# - Compraventa_Unitario muestra evidencia de cointegración, lo que sugiere que las variables incluidas tienen una tendencia a largo plazo a moverse juntas, manteniendo una relación de equilibrio.
#
# - Index_Turisme muestra evidencia de cointegración, lo que sugiere que las variables incluidas tienen una tendencia a largo plazo a moverse juntas, manteniendo una relación de equilibrio.

# %% [markdown]
# Para un análisis conjunto, dado que una de las series esta cointegrada y la otra no, se consideran principalmente 2 modelos, VAR y VECM

# %% [markdown]
# ### Prueba de estacionariedad

# %% [markdown]
# Necesitamos que los datos sean estacionarios para poder usar el modelo VAR. Vamos a averiguarlo haciendo un Test de Dickey-Fuller aumentado, a cada variable univariante que tiene nuestro dataset.

# %%
import statsmodels.tsa.stattools as sts

# %%
def augmented_dickey_fuller_statistics(time_series):
  result = sts.adfuller(time_series.values)
  print('p-value: %f' % result[1])

print('Test de Dickey-Fuller Aumentado:')
for i in range(len(X_train.columns)):
  print('Serie de tiempo',X_train.columns[i])
  augmented_dickey_fuller_statistics(X_train.iloc[:,i])
# Out:
# Test de Dickey-Fuller Aumentado:
# Serie de tiempo Compraventa_Unitario
# p-value: 0.480876
# Serie de tiempo Index_Turisme
# p-value: 0.781678

# %% [markdown]
# Los p-valores son mayores que 0.05, con lo cual no se rechaza la hipótesis nula de que la serie no es estacionaria. Habría que transformar los datos porque no se puede confirmar estacionariedad.

# %%
#Diferenciando por primera vez
X_train_transformed=X_train.diff().dropna()
X_train_transformed.head()
# Out:
#             Compraventa_Unitario  Index_Turisme
# Fecha
# 2019-02-01              0.000000            0.0
# 2019-03-01              0.000000            0.0
# 2019-04-01           -118.933333            0.0
# 2019-05-01              0.000000            0.0
# 2019-06-01              0.000000            0.0

# %%
# Plot
fig, axes = plt.subplots(nrows=2, ncols=1, dpi=120, figsize=(12,6))
for i, ax in enumerate(axes.flatten()):
    data = X_train_transformed[X_train_transformed.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(X_train_transformed.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
print('Test de Dickey-Fuller Aumentado 2da vez:')
for i in range(len(X_train_transformed.columns)):
  print('Serie de tiempo transformada', 'Variable', X_train_transformed.columns[i])
  augmented_dickey_fuller_statistics(X_train_transformed.iloc[:,i])
# Out:
# Test de Dickey-Fuller Aumentado 2da vez:
# Serie de tiempo transformada Variable Compraventa_Unitario
# p-value: 0.000014
# Serie de tiempo transformada Variable Index_Turisme
# p-value: 0.000003

# %% [markdown]
# Todos los p-valores son < 0.05 por lo tanto se podría concluir que con 1 orden de diferenciación se obtienen series estacionarias.

# %% [markdown]
# ### Modelo VAR

# %% [markdown]
# El modelo VAR es una extension del modelo ARIMA para multiples series temporales, es decir en vez de modelar una sola srie temporal, el VAR modela simultaneamente todas las series temporales de un sistema.
# Cada serie temporal se regresa en función de usus propios valores pasados y de los valores pasados de las otras series temporales.

# %%
from statsmodels.tsa.api import VAR

# %%
model = VAR(X_train_transformed)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# #### Seleccionando el orden del modelo

# %%
modelsel=model.select_order(8)
modelsel.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Los resultados de la selección del orden del modelo VAR indican que el orden de rezago 0 es el preferido, ya que muestra los valores mínimos en todos los criterios: AIC (10.05), BIC (10.15), FPE (2.326e+04), y HQIC (10.08). Esto sugiere que un modelo VAR sin rezagos es la mejor opción según estos criterios de evaluación.
#
# Se adopta VAR(6)

# %% [markdown]
# #### Ajustando el modelo

# %%
res = model.fit(maxlags=6)
res.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 28, May, 2024
# Time:                     17:29:59
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    12.5589
# Nobs:                     23.0000    HQIC:                   11.5981
# Log likelihood:          -168.937    FPE:                    106540.
# AIC:                      11.2753    Det(Omega_mle):         43487.3
# --------------------------------------------------------------------
# Results for equation Compraventa_Unitario
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                         -37.717352        92.997490           -0.406           0.685
# L1.Compraventa_Unitario         0.094972         0.538166            0.176           0.860
# L1.Index_Turisme              -16.608753        80.694138           -0.206           0.837
# L2.Compraventa_Unitario         0.094972         0.538166            0.176           0.860
# L2.Index_Turisme              -16.608753        80.694138           -0.206           0.837
# L3.Compraventa_Unitario         0.159268         0.549302            0.290           0.772
# L3.Index_Turisme              -41.239454        81.441606           -0.506           0.613
# L4.Compraventa_Unitario         0.020017         0.513100            0.039           0.969
# L4.Index_Turisme               -8.154856        70.779979           -0.115           0.908
# L5.Compraventa_Unitario         0.020017         0.513100            0.039           0.969
# L5.Index_Turisme               -8.154856        70.779979           -0.115           0.908
# L6.Compraventa_Unitario        -0.073301         0.526517           -0.139           0.889
# L6.Index_Turisme              -54.422288        70.793888           -0.769           0.442
# ==========================================================================================
#
# Results for equation Index_Turisme
# ==========================================================================================
#                              coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------------
# const                          -0.688244         0.675142           -1.019           0.308
# L1.Compraventa_Unitario         0.001733         0.003907            0.444           0.657
# L1.Index_Turisme               -0.303067         0.585822           -0.517           0.605
# L2.Compraventa_Unitario         0.001733         0.003907            0.444           0.657
# L2.Index_Turisme               -0.303067         0.585822           -0.517           0.605
# L3.Compraventa_Unitario        -0.001856         0.003988           -0.465           0.642
# L3.Index_Turisme                0.044175         0.591248            0.075           0.940
# L4.Compraventa_Unitario         0.000365         0.003725            0.098           0.922
# L4.Index_Turisme               -0.148805         0.513847           -0.290           0.772
# L5.Compraventa_Unitario         0.000365         0.003725            0.098           0.922
# L5.Index_Turisme               -0.148805         0.513847           -0.290           0.772
# L6.Compraventa_Unitario        -0.000171         0.003822           -0.045           0.964
# L6.Index_Turisme               -0.115528         0.513948           -0.225           0.822
# ==========================================================================================
#
# Correlation matrix of residuals
#                         Compraventa_Unitario  Index_Turisme
# Compraventa_Unitario                1.000000       0.875701
# Index_Turisme                       0.875701       1.000000

# %% [markdown]
# La correlación entre los residuos de "Compraventa_Unitario" y los residuos de "Index_Turisme" es de 0.829143, lo que sugiere una correlación positiva muy fuerte entre los residuos de estas dos variables en los datos.

# %%
res.is_stable()
# Out:
# True

# %%
X_train.columns
# Out:
# Index(['Compraventa_Unitario', 'Index_Turisme'], dtype='object')

# %% [markdown]
# ###### Causalidad de Granger

# %%
grangercaus=res.test_causality(['Index_Turisme'],['Compraventa_Unitario'],kind='f')
grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
grangercaus=res.test_causality(['Compraventa_Unitario'],['Index_Turisme'],kind='f')
grangercaus.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Como se puede observar, la causalidad de Granger nos indica que ninguna de las series temporales puede predecir la otra serie temporal

# %% [markdown]
# ###### Matriz de causalidad de Granger

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import grangercausalitytests
import warnings
warnings.filterwarnings("ignore")
maxlag=3
test = 'ssr_chi2test'
def grangers_causality_matrix(X_train_transformed, variables, test = 'ssr_chi2test', verbose=False):
  dataset = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
  for c in dataset.columns:
    for r in dataset.index:
      test_result = grangercausalitytests(X_train_transformed[[r,c]], maxlag=maxlag, verbose=False)
      p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
      if verbose:
        print(f'Y = {r}, X = {c}, P Values = {p_values}')
      min_p_value = np.min(p_values)
      dataset.loc[r,c] = min_p_value
  dataset.columns = [var + '_x' for var in variables]
  dataset.index = [var + '_y' for var in variables]
  return dataset
grangers_causality_matrix(X_train_transformed, variables = X_train_transformed.columns)
# Out:
#                         Compraventa_Unitario_x  Index_Turisme_x
# Compraventa_Unitario_y                  1.0000           0.9637
# Index_Turisme_y                         0.5028           1.0000

# %% [markdown]
# Con esta matriz queda claro que la serie temporal de Compraventa_Unitario no causa ni es causada por la otra serie temporal de ParadosReg

# %% [markdown]
# ### Diagnosis del modelo

# %% [markdown]
# ###### Residuos

# %%
residuals=res.resid

# %%
fig, axs = plt.subplots(2)
fig.suptitle('Gráficos de los residuos',fontsize=20)
fig.set_size_inches(18, 10)
[axs[i].plot(residuals.iloc[:,i]) for i in range(2)]
plt.show()

# %% [markdown]
# ###### Dickey - Fuller a los residuos

# %%
print('ADF de los Residuos, p-valores:')
[sts.adfuller(residuals.iloc[:,i])[1] for i in range(2)]
# Out:
# ADF de los Residuos, p-valores:
# [0.9501793342985213, 0.9413630213805849]

# %% [markdown]
# Todos los p-valores son < 0.1 por tanto se rechaza la hipótesis nula de que las 2 series de residuos no son estacionarias, por lo cual con un 90% de confianza se cree que son estacionarias.

# %% [markdown]
# ###### ACF de los Residuos

# %%
import statsmodels.graphics.tsaplots as sgt
[sgt.plot_acf(residuals.iloc[:,i], zero = False, lags = 6) for i in range(2)]
plt.show()

# %% [markdown]
# Conclusión: Los residuos del modelo no presentan estructura de autocorrelación, son estacionarios según los resultados de la prueba de Dickey - Fuller aumentada y en los gráficos se puede comprobar esto visualmente, entonces puede concluirse que son ruido blanco como es deseable.

# %% [markdown]
# #### Valores predichos

# %%
y_fitted = res.fittedvalues
fig, axs = plt.subplots(2)
fig.suptitle('Gráficos de los valores predichos por el modelo',fontsize=15)
fig.set_size_inches(18, 10)
[axs[i].plot(y_fitted.iloc[:,i]) for i in range(2)]
plt.show()

# %% [markdown]
# #### Pronósticos a futuro

# %% [markdown]
# Para pronosticar, al modelo VAR le podemos pasar hasta el número de orden de retraso de observaciones de los datos pasados. Esto se debe a que los términos en el modelo VAR son esencialmente los retrasos de las diversas series de tiempo en el conjunto de datos, por lo que debemos proporcionar tantos valores anteriores como lo indique el orden de retraso utilizado por el modelo. De lo contrario estaríamos introduciendo poca fiabilidad.

# %%
# Obtener el orden del modelo
lag_order = res.k_ar
print('Orden del modelo:', lag_order)
# Input data para hacer forecasting (pronósticos a futuro)
input_data = X_train_transformed.values[-lag_order:]
# Forecasting
pred = res.forecast(y=input_data, steps=6)
pred = (pd.DataFrame(pred, index=X_test.index, columns=X_test.columns + '_pred'))
print('Predicciones:')
pred
# Out:
# Orden del modelo: 6
# Predicciones:
#             Compraventa_Unitario_pred  Index_Turisme_pred
# Fecha
# 2021-07-01                 106.343853           -0.702125
# 2021-08-01                 -13.006044           -0.237327
# 2021-09-01                 -10.299562           -0.187940
# 2021-10-01                   2.221569           -0.853316
# 2021-11-01                  -5.620407           -0.229700
# 2021-12-01                  -4.413024           -0.181211

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12, 10))
res.plot_forecast(lag_order)
plt.tight_layout(h_pad = 1.15)
plt.show()

# %% [markdown]
# #### Invirtiendo la transformación de los pronósticos a la escala original

# %% [markdown]
# Los pronósticos se generan en la escala de los datos de entrenamiento utilizados por el modelo, es decir, son datos transformados. Entonces, para volver a ponerlos en su escala original, necesitamos des-diferenciarlos. La forma de invertir la diferenciación es sumar estas diferencias consecutivamente al número base. Una forma sencilla de hacerlo es determinar primero la suma acumulada y luego sumarla al número base. Este proceso se puede revertir agregando la observación en el paso de tiempo anterior al difference value. inverted(ts) = differenced(ts) + observation(ts-1)

# %%
# Invirtiendo la transformación teniendo en cuenta que hemos diferenciado dos veces
def invert_transformation(ds, df_forecast, second_diff=False):
    for col in ds.columns:
        # Undo the 2nd Differencing
        if second_diff:
            df_forecast[str(col)] = (ds[col].iloc[-1] - ds[col].iloc[-2]) + df_forecast[str(col)].cumsum()

        # Undo the 1st Differencing
        df_forecast[str(col)] = ds[col].iloc[-1] + df_forecast[str(col)].cumsum()

    return df_forecast

# %%
pred.columns=X_test.columns
output = invert_transformation(X_train, pred, second_diff=False)
output
# Out:
#             Compraventa_Unitario  Index_Turisme
# Fecha
# 2021-07-01           5654.927186     393.770849
# 2021-08-01           5641.921142     393.533523
# 2021-09-01           5631.621580     393.345582
# 2021-10-01           5633.843149     392.492267
# 2021-11-01           5628.222742     392.262567
# 2021-12-01           5623.809718     392.081356

# %%
# Actual vs Forecasted Plots
fig, axes = plt.subplots(nrows = int(len(X_train.columns)), ncols = 1, dpi = 100, figsize = (14,10))
mi_lista = ['€/m²', 'Indice de motoriación de turismos']

for i, (col,ax) in enumerate(zip(X_train.columns, axes.flatten())):
    df[col].plot(color = '#3949AB', legend = True, ax = ax)
    X_test[col].plot(color = '#F4511E', legend = True, ax = ax)
    output[col].plot(color = '#00FF00', legend = True, ax = ax).autoscale(axis =' x',tight = True)

    ax.set_title('Variable: ' + col + ' - Actual vs Forecast')
    ax.set_ylabel(mi_lista[i])  # Establecer etiqueta del eje y
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')

    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize = 6)

    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, ['Datos de entreno', 'Datos de test', 'Valores predichos'], loc='upper left', fontsize=8)

plt.tight_layout()
plt.savefig('actual_forecast.png')
plt.show()

# %% [markdown]
# #### Evaluando el modelo

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):

    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
for i in ['Compraventa_Unitario','Index_Turisme']:
    print(f'Evaluation metric for {i}')
    timeseries_evaluation_metrics_func(X_test[str(i)] , output[str(i)])
# Out:
# Evaluation metric for Compraventa_Unitario
# Evaluation metric results:-
# MSE is : 47276.53451502168
# MAE is : 215.16741386615436
# RMSE is : 217.4316778094252
# MAPE is : 3.6755003542535
# R2 is : -85.8965090013003
#
# Evaluation metric for Index_Turisme
# Evaluation metric results:-
# MSE is : 2.862582135790094
# MAE is : 1.5586164227563681
# RMSE is : 1.691916704743497
# MAPE is : 0.395113614089499
# R2 is : 0.0

# %% [markdown]
# Para "Compraventa_Unitario", los resultados de las métricas de evaluación indican que el modelo no es adecuado: MSE (47276.53), MAE (215.17), RMSE (217.43), MAPE (3.68%) y R2 (-85.90), lo que muestra un ajuste muy pobre y un error considerable. En contraste, para "Index_Turisme", las métricas indican un mejor rendimiento con MSE (2.86), MAE (1.56), RMSE (1.69), MAPE (0.40%) y R2 (0.0), aunque el R2 de 0.0 sugiere que el modelo no explica la variabilidad de los datos de forma significativa.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print('Mean absolute error:', mean_absolute_error(X_test, output))
print('Root mean squared error:', np.sqrt(mean_squared_error(X_test, output)))
# Out:
# Mean absolute error: 108.36301514445536
# Root mean squared error: 153.75206843674897

# %% [markdown]
# ###Modelo VECM (Vector Error Correction Model)

# %% [markdown]
# ####Ajustando el modelo

# %%
from statsmodels.tsa.vector_ar.vecm import select_order

# %%
# Seleccionar el número óptimo de retardos basado en criterios de información
order_selection = select_order(X_train, maxlags=6) #Dado que una de las series tiene datos trimestrales(8) y la otra anual(30)
print(order_selection.summary())
# Out:
#  VECM Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0      10.21*      10.51*  2.730e+04*      10.29*
# 1       10.48       10.97   3.612e+04       10.60
# 2       10.67       11.36   4.496e+04       10.85
# 3       10.77       11.66   5.213e+04       11.00
# 4       10.98       12.06   6.929e+04       11.25
# 5       10.90       12.19   7.342e+04       11.23
# 6       11.21       12.69   1.221e+05       11.58
# -------------------------------------------------

# %%
from statsmodels.tsa.vector_ar.vecm import VECM

# %%
# Usar el número óptimo de retardos seleccionado
optimal_lags = order_selection.aic  # Por ejemplo, puedes usar el criterio AIC
model = VECM(X_train, k_ar_diff=optimal_lags)

# %%
vecm_fit = model.fit()

# %%
vecm_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#         Loading coefficients (alpha) for equation Compraventa_Unitario
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0337      0.050     -0.672      0.501      -0.132       0.064
#            Loading coefficients (alpha) for equation Index_Turisme
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1            0.0003      0.000      0.869      0.385      -0.000       0.001
#           Cointegration relations for loading-coefficients-column 1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1         1.0000          0          0      0.000       1.000       1.000
# beta.2       -14.6149      0.653    -22.371      0.000     -15.895     -13.334
# ==============================================================================
# """

# %% [markdown]
# Existe una relación de cointegración significativa y fuerte entre las variables, indicando una influencia estable y negativa de largo plazo de Index_Turisme sobre Compraventa_Unitario. Este resultado resalta la importancia de la relación de largo plazo, aunque el ajuste en el corto plazo parece ser deficiente, lo que puede requerir la revisión del modelo o la inclusión de más variables explicativas.

# %%
stability_test = vecm_fit.test_whiteness(nlags=12)
print(stability_test.summary())
# Out:
# Portmanteau-test for residual autocorrelation. H_0: residual autocorrelation up to lag 12 is zero. Conclusion: fail to reject H_0 at 5% significance level.
# ========================================
# Test statistic Critical value p-value df
# ----------------------------------------
#          39.97          62.83   0.722 46
# ----------------------------------------

# %% [markdown]
# ####Diagnosis del modelo

# %% [markdown]
# #####Residuos

# %%
residuals=vecm_fit.resid

# %%
fig, axs = plt.subplots(2)
fig.suptitle('Gráficos de los residuos',fontsize=20)
fig.set_size_inches(18, 10)
[axs[i].plot(residuals[i]) for i in range(2)]
plt.show()

# %% [markdown]
# #####Dickey - Fuller a los residuos

# %%
import statsmodels.tsa.stattools as ts

# %%
# Realizar la prueba ADF en cada serie de residuos y imprimir los resultados
print('ADF de los Residuos, p-valores:')
for i in range(residuals.shape[1]):
    result = ts.adfuller(residuals[:, i])
    print(f'Variable {i+1}: Estadístico ADF = {result[0]:.4f}, P-valor = {result[1]:.4f}')
# Out:
# ADF de los Residuos, p-valores:
# Variable 1: Estadístico ADF = -5.0637, P-valor = 0.0000
# Variable 2: Estadístico ADF = -5.4421, P-valor = 0.0000

# %% [markdown]
# #####ACF de los Residuos

# %%
import statsmodels.api as sm

# %%
# Realizar y graficar la función de autocorrelación para cada serie de residuos
fig, axes = plt.subplots(nrows=residuals.shape[1], ncols=1, figsize=(10, 10))
for i in range(residuals.shape[1]):
    sm.graphics.tsa.plot_acf(residuals[:, i], lags=12, ax=axes[i], title=f'AFC de Residuos - Variable {i+1}')
    axes[i].set_ylabel('Autocorrelación')
    axes[i].set_xlabel('Retardos')

# %% [markdown]
# Esto sugiere que los residuos de la Variable 1 y 2 son aproximadamente ruido blanco, indicando un buen ajuste del modelo para esta variable. No hay evidencia de autocorrelaciones remanentes que el modelo no haya capturado.

# %% [markdown]
# ####Valores predichos

# %%
y_fitted = vecm_fit.fittedvalues
fig, axs = plt.subplots(2)
fig.suptitle('Gráficos de los valores predichos por el modelo',fontsize=15)
fig.set_size_inches(18, 10)
[axs[i].plot(y_fitted[i]) for i in range(2)]
plt.show()

# %% [markdown]
# ####Pronósticos a futuro

# %%
# Obtener los últimos valores (lag_order número de valores)
lag_order = vecm_fit.k_ar
last_observations = data[-lag_order:]

# Hacer predicciones para los próximos n pasos
n_steps = 6
forecast = vecm_fit.predict(n_steps)

pred = (pd.DataFrame(forecast, index=X_test.index, columns=X_test.columns))
pred
# Out:
#             Compraventa_Unitario  Index_Turisme
# Fecha
# 2021-07-01           5555.878918     394.405042
# 2021-08-01           5562.895343     394.339710
# 2021-09-01           5569.643288     394.276878
# 2021-10-01           5576.133027     394.216450
# 2021-11-01           5582.374441     394.158334
# 2021-12-01           5588.377031     394.102442

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12, 10))
vecm_fit.plot_forecast(lag_order)
plt.tight_layout(h_pad = 1.15)
plt.show()

# %%
# Actual vs Forecasted Plots
fig, axes = plt.subplots(nrows = int(len(X_train.columns)), ncols = 1, dpi = 100, figsize = (14,10))
mi_lista = ['€/m²', 'Indice de motorizacion de turismos']

for i, (col,ax) in enumerate(zip(X_train.columns, axes.flatten())):
    df[col].plot(color = '#3949AB', legend = True, ax = ax)
    X_test[col].plot(color = '#F4511E', legend = True, ax = ax)
    pred[col].plot(color = '#00FF00', legend = True, ax = ax).autoscale(axis =' x',tight = True)

    ax.set_title('Variable: ' + col + ' - Actual vs Forecast')
    ax.set_ylabel(mi_lista[i])  # Establecer etiqueta del eje y
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')

    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize = 6)

    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, ['Datos de entreno', 'Datos de test', 'Valores predichos'], loc='upper left', fontsize=8)

plt.tight_layout()
plt.savefig('actual_forecast.png')
plt.show()

# %% [markdown]
# ####Evaluando el modelo

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):

    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
for i in ['Compraventa_Unitario','Index_Turisme']:
    print(f'Evaluation metric for {i}')
    timeseries_evaluation_metrics_func(X_test[str(i)] , pred[str(i)])
# Out:
# Evaluation metric for Compraventa_Unitario
# Evaluation metric results:-
# MSE is : 77686.60833494805
# MAE is : 278.3413253844985
# RMSE is : 278.7231750948386
# MAPE is : 4.756396535556936
# R2 is : -141.7916646114011
#
# Evaluation metric for Index_Turisme
# Evaluation metric results:-
# MSE is : 0.06048717584623762
# MAE is : 0.22316413667859555
# RMSE is : 0.24594140734377695
# MAPE is : 0.05657273161687051
# R2 is : 0.0

# %% [markdown]
# Los resultados de los métricos de evaluación indican que el modelo para Compraventa_Unitario tiene un desempeño deficiente, con un MSE alto y un R² negativo, sugiriendo que no explica bien la variabilidad de los datos. En contraste, el modelo para Index_Turisme muestra un MSE muy bajo y un R² de 0.0, indicando un ajuste casi perfecto y una mínima diferencia entre los valores predichos y reales. La precisión en Index_Turisme es notablemente mejor, reflejada en su bajo MAE, RMSE y MAPE.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print('Mean absolute error:', mean_absolute_error(X_test, pred))
print('Root mean squared error:', np.sqrt(mean_squared_error(X_test, pred)))
# Out:
# Mean absolute error: 139.28224476058853
# Root mean squared error: 197.08712390986364

# %% [markdown]
# ##Conclusiones

# %% [markdown]
# En este proyecto, se analizaron y compararon diferentes modelos de series temporales para pronosticar dos indicadores: "Compraventa_Unitario" e "Index_Turisme". Se realizaron pruebas de cointegración y estacionariedad, confirmando la necesidad de transformar las series para hacerlas estacionarias. Los modelos VAR y VECM fueron seleccionados para el análisis debido a la naturaleza de las variables.
#
# El modelo VAR mostró una correlación muy fuerte entre los residuos de las variables, pero las pruebas de causalidad de Granger indicaron que ninguna serie puede predecir a la otra de manera significativa. Además, las métricas de evaluación revelaron un rendimiento deficiente del modelo VAR para "Compraventa_Unitario", mientras que el rendimiento para "Index_Turisme" fue moderadamente aceptable.
#
# El modelo VECM, por otro lado, destacó una relación de cointegración significativa entre las variables, sugiriendo una influencia estable de largo plazo de "Index_Turisme" sobre "Compraventa_Unitario". Sin embargo, las métricas de evaluación nuevamente señalaron un ajuste insatisfactorio para "Compraventa_Unitario" y un ajuste casi perfecto para "Index_Turisme".
#
# En resumen, mientras que el modelo VECM demostró ser superior al VAR en términos de estabilidad y relaciones de largo plazo, ambos modelos presentaron desafíos significativos en la predicción precisa de "Compraventa_Unitario". Los resultados sugieren la necesidad de explorar modelos adicionales o incluir más variables explicativas para mejorar la precisión predictiva.
